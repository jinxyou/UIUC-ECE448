# %% [markdown]
# # CS440/ECE448 Spring 2023
# # MP11: Reinforcement Learning

# %% [markdown]
# The first thing you need to do is to download this file: <a href="mp11.zip">mp11.zip</a>.  If you want, you can also download <a href="mp11_extra.zip">mp11_extra.zip</a>, the extra credit assignment.  `mp11.zip` has the following content:
#
# * `submitted.py`: Your homework. Edit, and then submit to <a href="https://www.gradescope.com/courses/486387">Gradescope</a>.
# * `mp11_notebook.ipynb`: This is a <a href="https://anaconda.org/anaconda/jupyter">Jupyter</a> notebook to help you debug.  You can completely ignore it if you want, although you might find that it gives you useful instructions.
# * `pong.py`: This is a program that plays Pong.  If called interactively, it will call the module `pong_display.py` to create a display, so that you can play.  If told to use a Q-learner, it will call your `submitted.py` to do Q-learning.
# * `grade.py`: Once your homework seems to be working, you can test it by typing `python grade.py`, which will run the tests in `tests/tests_visible.py`.
# * `tests/test_visible.py`: This file contains about half of the <a href="https://docs.python.org/3/library/unittest.html">unit tests</a> that Gradescope will run in order to grade your homework.  If you can get a perfect score on these tests, then you should also get a perfect score on the additional hidden tests that Gradescope uses.
# * `requirements.txt`: This tells you which python packages you need to have installed, in order to run `grade.py`.  You can install all of those packages by typing `pip install -r requirements.txt` or `pip3 install -r requirements.txt`.

# %% [markdown]
# This file (`mp11_notebook.ipynb`) will walk you through the whole MP, giving you instructions and debugging tips as you go.
#
# ### Table of Contents
#
# 1. <a href="#section1">Playing Pong</a>
# 1. <a href="#section2">Creating a Q-Learner Object</a>
# 1. <a href="#section3">Epsilon-First Exploration</a>
# 1. <a href="#section4">Q-Learning</a>
# 1. <a href="#section5">Saving and Loading Your Q and N Tables</a>
# 1. <a href="#section6">Exploitation</a>
# 1. <a href="#section7">Acting</a>
# 1. <a href="#section8">Training</a>
# 1. <a href="#section9">Extra Credit</a>
# 1. <a href="#grade">Grade Your Homework</a>

# %% [markdown]
# <a id='section1'></a>

# %% [markdown]
# ## Playing Pong

# %% [markdown]
# Pong was the <a href="https://en.wikipedia.org/wiki/Pong">first video game produced by Atari.</a>  It is a simple game, based on table tennis.  Here is a two-person version of the game: https://commons.wikimedia.org/wiki/File:Pong_Game_Test2.gif
#
# We will be playing a one-person version of the game:
#
# * When the ball hits the top, bottom, or left wall of the playing field, it bounces.
# * The right end of the playing field is open, except for the paddle.  If the ball hits the paddle, it bounces, and the player's score increments by one.  If the ball hits the open space, the game is over; the score resets to zero, and a new game begins.
#
# The game is pretty simple, but in order to get a better feeling for it, you may want to try playing it yourself.  Use the up arrow to move the paddle upward, and the down arrow to move the paddle downward.  See how high you can make your score:

# %%
# !python pong.py
# Out:
# pygame 2.2.0 (SDL 2.0.22, Python 3.9.13)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %% [markdown]
# Once you figure out how to use the arrow keys to control your paddle, we hope you will find that the game is not too hard for a human to play.  However, for a computer, it's difficult to know: where should the paddle be moved at each time step?  In order to see how difficult it is for a computer to play, let's ask the "random" player to play the game.
#
# **WARNING:** The following line will open a pygame window.  The pygame window will be hidden by this window -- in order to see it, you will need to minimize this window.  The pygame window will consume a lot of CPU time just waiting for the processor, so in order to kill it, you will need to come back to this window, click on the block below, then click the Jupyter "stop" button (the square button at the top of this window) in order to stop processing.

# %%
# !python pong.py --player random
# Out:
# pygame 2.2.0 (SDL 2.0.22, Python 3.9.13)
# Hello from the pygame community. https://www.pygame.org/contribute.html
# Completed 0 games, 1 rewards, 209 frames, score 0, max score 0
# Completed 1 games, 4 rewards, 689 frames, score 2, max score 2
# Completed 2 games, 5 rewards, 870 frames, score 0, max score 2
# ^C
# Traceback (most recent call last):
#   File "/Users/jyou/Documents/ECE448/mp11/pong.py", line 270, in <module>
#     application.run()
#   File "/Users/jyou/Documents/ECE448/mp11/pong.py", line 170, in run
#     self.display.update_display()
#   File "/Users/jyou/Documents/ECE448/mp11/pong_display.py", line 65, in update_display
#     self.fps.tick(60)
# KeyboardInterrupt

# %% [markdown]
# <a id='section2'></a>

# %% [markdown]
# ## Creating a Q-Learner Object

# %% [markdown]
# The first thing you will do is to create a `q_learner` object that can store your learned Q table and your N table (table of exploration counts).
#
# Like any other object-oriented language, python permits you to create new object classes in order to store data that will be needed from time to time.  If you are not already very, very familiar with python classes, you might want to study the python class tutorial: https://docs.python.org/3/tutorial/classes.html
#
# Like any other object in python, a `q_learner` object is created by calling its name as a function, e.g., `my_q_learner=submitted.q_learner()`.  Doing so calls the function `submitted.q_learner.__init__()`.  Let's look at the docstring to see what it should do.

# %%
import submitted, importlib
importlib.reload(submitted)
help(submitted.q_learner.__init__)
# Out:
# Help on function __init__ in module submitted:
#
# __init__(self, alpha, epsilon, gamma, nfirst, state_cardinality)
#     Create a new q_learner object.
#     Your q_learner object should store the provided values of alpha,
#     epsilon, gamma, and nfirst.
#     It should also create a Q table and an N table.
#     Q[...state..., ...action...] = expected utility of state/action pair.
#     N[...state..., ...action...] = # times state/action has been explored.
#     Both are initialized to all zeros.
#     Up to you: how will you encode the state and action in order to
#     define these two lookup tables?  The state will be a list of 5 integers,
#     such that 0 <= state[i] < state_cardinality[i] for 0 <= i < 5.
#     The action will be either -1, 0, or 1.
#     It is up to you to decide how to convert an input state and action
#     into indices that you can use to access your stored Q and N tables.
#
#     @params:
#     alpha (scalar) - learning rate of the Q-learner
#     epsilon (scalar) - probability of taking a random action
#     gamma (scalar) - discount factor
#     nfirst (scalar) - exploring each state/action pair nfirst times before exploiting
#     state_cardinality (list) - cardinality of each of the quantized state variables
#
#     @return:
#     None

# %% [markdown]
# Write your `__init__` function to meet the requirements specified in the docstring.  Once you have completed it, the following code should run without errors:

# %%
importlib.reload(submitted)

q_learner = submitted.q_learner(0.05,0.05,0.99,5,[10,10,2,2,10])

print(q_learner)
# Out:
# <submitted.q_learner object at 0x7f9f4093bd90>

# %% [markdown]
# <a id='section3'></a>

# %% [markdown]
# ## Epsilon-First Exploration

# %% [markdown]
# In order to manage the exploration/exploitation tradeoff, we will be using both "epsilon-first" and "epsilon-greedy" (https://en.wikipedia.org/wiki/Multi-armed_bandit#Semi-uniform_strategies).
#
# The epsilon-first strategy explores every state/action pair at least `nfirst` times before it ever starts to exploit any strategy.  Your `q_learner` should have a table to keep track of how many times it has explored a state/action pair prior to the start of any exploitation.  The method for storing that table is up to you; in order to have some standardized API, therefore, you need to write a method called `report_exploration_counts` that returns a list of the three exploration counts for a given state.

# %%
importlib.reload(submitted)
help(submitted.q_learner.report_exploration_counts)
# Out:
# Help on function report_exploration_counts in module submitted:
#
# report_exploration_counts(self, state)
#     Check to see how many times each action has been explored in this state.
#     @params:
#     state (list of 5 ints): ball_x, ball_y, ball_vx, ball_vy, paddle_y.
#       These are the (x,y) position of the ball, the (vx,vy) velocity of the ball,
#       and the y-position of the paddle, all quantized.
#       0 <= state[i] < state_cardinality[i], for all i in [0,4].
#
#     @return:
#     explored_count (array of 3 ints):
#       number of times that each action has been explored from this state.
#       The mapping from actions to integers is up to you, but there must be three of them.

# %% [markdown]
# Write `report_exploration_counts` so that it returns a list or array for any given state.  Test your code with the following:

# %%
importlib.reload(submitted)
q_learner = submitted.q_learner(0.05,0.05,0.99,5,[10,10,2,2,10])
print('This is how many times state [0,0,0,0,0] has been explored so far:')
print(q_learner.report_exploration_counts([0,0,0,0,0]))
print('This is how many times state [9,9,1,1,9] has been explored so far:')
print(q_learner.report_exploration_counts([9,9,1,1,9]))
# Out:
# This is how many times state [0,0,0,0,0] has been explored so far:
# [0. 0. 0.]
# This is how many times state [9,9,1,1,9] has been explored so far:
# [0. 0. 0.]

# %% [markdown]
# When your learner first starts learning, it will call the function `choose_unexplored_action` to choose an unexplored action.  This function should choose a function uniformly at random from the set of unexplored actions in a given state, if there are any:

# %%
importlib.reload(submitted)
help(submitted.q_learner.choose_unexplored_action)
# Out:
# Help on function choose_unexplored_action in module submitted:
#
# choose_unexplored_action(self, state)
#     Choose an action that has been explored less than nfirst times.
#     If many actions are underexplored, you should choose uniformly
#     from among those actions; don't just choose the first one all
#     the time.
#
#     @params:
#     state (list of 5 ints): ball_x, ball_y, ball_vx, ball_vy, paddle_y.
#        These are the (x,y) position of the ball, the (vx,vy) velocity of the ball,
#       and the y-position of the paddle, all quantized.
#       0 <= state[i] < state_cardinality[i], for all i in [0,4].
#
#     @return:
#     action (scalar): either -1, or 0, or 1, or None
#       If all actions have been explored at least n_explore times, return None.
#       Otherwise, choose one uniformly at random from those w/count less than n_explore.
#       When you choose an action, you should increment its count in your counter table.

# %% [markdown]
# If this has been written correctly, the following block should generate a random sequence of actions.  If the next block produces the same action 5 times in a row, that is the wrong result, and the result would be that your code does not pass the autograder.

# %%
importlib.reload(submitted)
q_learner = submitted.q_learner(0.05,0.05,0.99,5,[10,10,2,2,10])
print('Next action:',q_learner.choose_unexplored_action([9,9,1,1,9]))
print('Next action:',q_learner.choose_unexplored_action([9,9,1,1,9]))
print('Next action:',q_learner.choose_unexplored_action([9,9,1,1,9]))
print('Next action:',q_learner.choose_unexplored_action([9,9,1,1,9]))
print('Next action:',q_learner.choose_unexplored_action([9,9,1,1,9]))
# Out:
# Next action: -1
# Next action: -1
# Next action: -1
# Next action: 0
# Next action: -1

# %% [markdown]
# After all three actions have been explored `nfirst` times, the function `choose_unexplored_action` should return `None`, as shown here:

# %%
importlib.reload(submitted)
q_learner = submitted.q_learner(0.05,0.05,0.99,1,[10,10,2,2,10])
print('Next action:',q_learner.choose_unexplored_action([9,9,1,1,9]))
print('Next action:',q_learner.choose_unexplored_action([9,9,1,1,9]))
print('Next action:',q_learner.choose_unexplored_action([9,9,1,1,9]))
print('Next action:',q_learner.choose_unexplored_action([9,9,1,1,9]))
# Out:
# Next action: 0
# Next action: -1
# Next action: 1
# Next action: None

# %% [markdown]
# <a id='section4'></a>

# %% [markdown]
# ## Q-Learning

# %% [markdown]
# The reinforcement learning we are implementing is called Q-learning (https://en.wikipedia.org/wiki/Q-learning).
#
# Q-learning keeps a table $Q[s,a]$ that specifies the expected utility of action $a$ in state $s$.  The organization of this table is up to you.  In order to have a standard API, the first thing you should implement is a function `report_q` with the following docstring:

# %%
importlib.reload(submitted)
help(submitted.q_learner.report_q)
# Out:
# Help on function report_q in module submitted:
#
# report_q(self, state)
#     Report the current Q values for the given state.
#     @params:
#     state (list of 5 ints): ball_x, ball_y, ball_vx, ball_vy, paddle_y.
#       These are the (x,y) position of the ball, the (vx,vy) velocity of the ball,
#       and the y-position of the paddle, all quantized.
#       0 <= state[i] < state_cardinality[i], for all i in [0,4].
#
#     @return:
#     Q (array of 3 floats):
#       reward plus expected future utility of each of the three actions.
#       The mapping from actions to integers is up to you, but there must be three of them.

# %% [markdown]
# When your `q_learner` is first initialized, the value of $Q[state,action]$ should be zero for all state/action pairs, thus the `report_q` function should return lists of zeros:

# %%
importlib.reload(submitted)
q_learner=submitted.q_learner(0.05,0.05,0.99,5,[10,10,2,2,10])
print('Q[0,0,0,0,0] is now:',q_learner.report_q([0,0,0,0,0]))
print('Q[9,9,1,1,9] is now:',q_learner.report_q([9,9,1,1,9]))
# Out:
# Q[0,0,0,0,0] is now: [0. 0. 0.]
# Q[9,9,1,1,9] is now: [0. 0. 0.]

# %% [markdown]
# There are actually many different Q-learning algorithms available, but when people refer to Q-learning with no modifier, they usually mean the time-difference (TD) algorithm.  For example, this is the algorithm that's described on the wikipedia page (https://en.wikipedia.org/wiki/Q-learning).  This is the algorithm you will implement for this MP.
#
# In supervised machine learning, the learner tries to imitate a reference label.  In reinforcement learning, there is no reference label.  Q-learning replaces the reference label with a "local Q" value, which is the utility that was obtained by performing action $a$ in state $s$ one time.  It is usually calculated like this:
#
# $$Q_{local}(s_t,a_t) = r_t + \gamma\max_{a_{t+1}}Q(s_{t+1},a_{t+1})$$
#
# where $r_t$ is the reward that was achieved by performing action $a_t$ in state $s_t$, $s_{t+1}$ is the state into which the game transitioned, and $a_{t+1}$ is one of the actions that could be performed in that state.  $Q_{local}$ is computed by your `q_local` function, which has this docstring:

# %%
importlib.reload(submitted)
help(submitted.q_learner.q_local)
# Out:
# Help on function q_local in module submitted:
#
# q_local(self, reward, newstate)
#     The update to Q estimated from a single step of game play:
#     reward plus gamma times the max of Q[newstate, ...].
#
#     @param:
#     reward (scalar float): the reward achieved from the current step of game play.
#     newstate (list of 5 ints): ball_x, ball_y, ball_vx, ball_vy, paddle_y.
#       These are the (x,y) position of the ball, the (vx,vy) velocity of the ball,
#       and the y-position of the paddle, all quantized.
#       0 <= state[i] < state_cardinality[i], for all i in [0,4].
#
#     @return:
#     Q_local (scalar float): the local value of Q

# %% [markdown]
# Initially, `q_local` should just return the given reward, because initially, all Q values are 0:

# %%
importlib.reload(submitted)
q_learner = submitted.q_learner(0.05,0.05,0.99,5,[10,10,2,10,10])
print('Q_local(6.25,[9,9,1,1,9]) is currently:',q_learner.q_local(6.25,[9,9,1,1,9]))
# Out:
# Q_local(6.25,[9,9,1,1,9]) is currently: 6.25

# %% [markdown]
# Now you can use `q_learner.q_local` as the target for `q_learner.learn`.  The basic algorithm is
#
# $$Q(s,a) = Q(s,a) + \alpha (Q_{local}(s,a)-Q(s,a))$$
#
# Here is the docstring:

# %%
importlib.reload(submitted)
help(submitted.q_learner.learn)
# Out:
# Help on function learn in module submitted:
#
# learn(self, state, action, reward, newstate)
#     Update the internal Q-table on the basis of an observed
#     state, action, reward, newstate sequence.
#
#     @params:
#     state: a list of 5 numbers: ball_x, ball_y, ball_vx, ball_vy, paddle_y.
#       These are the (x,y) position of the ball, the (vx,vy) velocity of the ball,
#       and the y-position of the paddle.
#     action: an integer, one of -1, 0, or +1
#     reward: a reward; positive for hitting the ball, negative for losing a game
#     newstate: a list of 5 numbers, in the same format as state
#
#     @return:
#     None

# %% [markdown]
# The following block checks a sequence of Q updates:
#
# 1. First, $Q([9,9,1,1,9],-1)$ is updated.  Since all Q values start at zero, it will be updated to just have a value equal to $\alpha$ (0.05) times the given reward (6.25) for a total value of 0.3125.
# 1. When we print out $Q([9,9,1,1,9],:)$, we see that one of the elements has been updated.
# 1. Next, update $Q([9,9,1,1,8],1)$ with a given reward, and with $[9,9,1,1,9]$ as the given next state.  Since $Q([9,9,1,1,9],-1)$ is larger than zero, the next-state Q-value should be multiplied by $\gamma$ (0.99) and added to the reward (3.1), then multiplied by $\alpha$, giving a total value of 0.17046875.
# 1. The resulting Q-value is reported.

# %%
importlib.reload(submitted)
q_learner = submitted.q_learner(0.05,0.05,0.99,5,[10,10,2,2,10])
q_learner.learn([9,9,1,1,9],-1,6.25,[0,0,0,0,0])
print('Q[9,9,1,1,9] is now',q_learner.report_q([9,9,1,1,9]))
q_learner.learn([9,9,1,1,8],1,3.1,[9,9,1,1,9])
print('Q[9,9,1,1,8] is now',q_learner.report_q([9,9,1,1,8]))
# Out:
# Q[9,9,1,1,9] is now [0.3125 0.     0.    ]
# Q[9,9,1,1,8] is now [0.         0.         0.17046875]

# %% [markdown]
# <a id='section5'></a>

# %% [markdown]
# ## Saving and Loading your Q and N Tables

# %% [markdown]
# After you've spent a long time training your `q_learner`, you will want to save your Q and N tables so that you can reload them later.  The format of Q and N is up to you, therefore it's also up to you to write the `save` and `load` functions.  Here are the docstrings:

# %%
importlib.reload(submitted)
help(submitted.q_learner.save)
# Out:
# Help on function save in module submitted:
#
# save(self, filename)
#     Save your Q and N tables to a file.
#     This can save in any format you like, as long as your "load"
#     function uses the same file format.  We recommend numpy.savez,
#     but you can use something else if you prefer.
#
#     @params:
#     filename (str) - filename to which it should be saved
#     @return:
#     None

# %%
importlib.reload(submitted)
help(submitted.q_learner.load)
# Out:
# Help on function load in module submitted:
#
# load(self, filename)
#     Load the Q and N tables from a file.
#     This should load from whatever file format your save function
#     used.  We recommend numpy.load, but you can use something
#     else if you prefer.
#
#     @params:
#     filename (str) - filename from which it should be loaded
#     @return:
#     None

# %% [markdown]
# These functions can be tested by doing one step of training one `q_learner`, then saving its results, then loading them into another `q_learner`:

# %%
importlib.reload(submitted)
q_learner1 = submitted.q_learner(0.05,0.05,0.99,5,[10,10,2,2,10])
print('Next action:',q_learner1.choose_unexplored_action([9,9,1,1,9]))
q_learner1.learn([9,9,1,1,9],-1,6.25,[0,0,0,0,0])
print('N1[9,9,1,1,8] is now',q_learner1.report_exploration_counts([9,9,1,1,9]))
print('Q1[9,9,1,1,8] is now',q_learner1.report_q([9,9,1,1,9]))
q_learner1.save('test.npz')

q_learner2 = submitted.q_learner(0.05,0.05,0.99,5,[10,10,2,2,10])
print('N2[9,9,1,1,8] starts out as',q_learner2.report_exploration_counts([9,9,1,1,9]))
print('Q2[9,9,1,1,8] starts out as',q_learner2.report_q([9,9,1,1,9]))
q_learner2.load('test.npz')
print('N2[9,9,1,1,8] is now',q_learner2.report_exploration_counts([9,9,1,1,9]))
print('Q2[9,9,1,1,8] is now',q_learner2.report_q([9,9,1,1,9]))
# Out:
# Next action: 0
# N1[9,9,1,1,8] is now [1. 1. 0.]
# Q1[9,9,1,1,8] is now [0.3125 0.     0.    ]
# N2[9,9,1,1,8] starts out as [0. 0. 0.]
# Q2[9,9,1,1,8] starts out as [0. 0. 0.]
# N2[9,9,1,1,8] is now [1. 1. 0.]
# Q2[9,9,1,1,8] is now [0.3125 0.     0.    ]

# %% [markdown]
# <a id='section6'></a>

# %% [markdown]
# ## Exploitation

# %% [markdown]
# A reinforcement learner always has to trade off between exploration (choosing an action at random) versus exploitation (choosing the action with the maximum expected utility).  Before we worry about that tradeoff, though, let's first make sure that exploitation works.

# %%
importlib.reload(submitted)
help(submitted.q_learner.exploit)
# Out:
# Help on function exploit in module submitted:
#
# exploit(self, state)
#     Return the action that has the highest Q-value for the current state, and its Q-value.
#     @params:
#     state (list of 5 ints): ball_x, ball_y, ball_vx, ball_vy, paddle_y.
#       These are the (x,y) position of the ball, the (vx,vy) velocity of the ball,
#       and the y-position of the paddle, all quantized.
#       0 <= state[i] < state_cardinality[i], for all i in [0,4].
#
#     @return:
#     action (scalar int): either -1, or 0, or 1.
#       The action that has the highest Q-value.  Ties can be broken any way you want.
#     Q (scalar float):
#       The Q-value of the selected action

# %%
importlib.reload(submitted)
q_learner1 = submitted.q_learner(0.05,0.05,0.99,5,[10,10,2,2,10])
q_learner1.learn([9,9,1,1,9],-1,6.25,[0,0,0,0,0])
print('Q1[9,9,1,1,9] is now',q_learner1.report_q([9,9,1,1,9]))
print('The best action and Q from state [9,9,1,1,9] are',q_learner1.exploit([9,9,1,1,9]))
# Out:
# Q1[9,9,1,1,9] is now [0.3125 0.     0.    ]
# The best action and Q from state [9,9,1,1,9] are (-1, 0.3125)

# %% [markdown]
# <a id='section7'></a>

# %% [markdown]
# ## Acting

# %% [markdown]
# When your learner decides which action to perform, it should trade off exploration vs. exploitation using both the epsilon-first and the epsilon-greedy strategies:
# 1. If there is any action that has been explored fewer than `nfirst` times, then choose one of those actions at random.  Otherwise...
# 1. With probability `epsilon`, choose an action at random.  Otherwise...
# 1. Exploit.

# %%
importlib.reload(submitted)
help(submitted.q_learner.act)
# Out:
# Help on function act in module submitted:
#
# act(self, state)
#     Decide what action to take in the current state.
#     If any action has been taken less than nfirst times, then choose one of those
#     actions, uniformly at random.
#     Otherwise, with probability epsilon, choose an action uniformly at random.
#     Otherwise, choose the action with the best Q(state,action).
#
#     @params:
#     state: a list of 5 integers: ball_x, ball_y, ball_vx, ball_vy, paddle_y.
#       These are the (x,y) position of the ball, the (vx,vy) velocity of the ball,
#       and the y-position of the paddle, all quantized.
#       0 <= state[i] < state_cardinality[i], for all i in [0,4].
#
#     @return:
#     -1 if the paddle should move upward
#     0 if the paddle should be stationary
#     1 if the paddle should move downward

# %% [markdown]
# In order to test all three types of action (epsilon-first exploration, epsilon-greedy exploration, and exploitation), let's create a learner with `nfirst=1` and `epsilon=0.25`, and set it so that the best action from state `[9,9,1,1,9]` is `-1`.  With these settings, a sequence of calls to `q_learner.act` should produce the following sequence of actions:
#
# 1. The first three actions should include each possible action once.
# 1. After the first three actions, 3/4 of the remaining actions should be `-1`.  The remaining 1/4 should be randomly chosen.

# %%
importlib.reload(submitted)
q_learner=submitted.q_learner(0.05,0.25,0.99,1,[10,10,2,2,10])
q_learner.learn([9,9,1,1,9],-1,6.25,[0,0,0,0,0])
print('An epsilon-first action:',q_learner.act([9,9,1,1,9]))
print('An epsilon-first action:',q_learner.act([9,9,1,1,9]))
print('An epsilon-first action:',q_learner.act([9,9,1,1,9]))
print('An epsilon-greedy explore/exploit action:',q_learner.act([9,9,1,1,9]))
print('An epsilon-greedy explore/exploit action:',q_learner.act([9,9,1,1,9]))
print('An epsilon-greedy explore/exploit action:',q_learner.act([9,9,1,1,9]))
print('An epsilon-greedy explore/exploit action:',q_learner.act([9,9,1,1,9]))
print('An epsilon-greedy explore/exploit action:',q_learner.act([9,9,1,1,9]))
print('An epsilon-greedy explore/exploit action:',q_learner.act([9,9,1,1,9]))
print('An epsilon-greedy explore/exploit action:',q_learner.act([9,9,1,1,9]))
print('An epsilon-greedy explore/exploit action:',q_learner.act([9,9,1,1,9]))
print('An epsilon-greedy explore/exploit action:',q_learner.act([9,9,1,1,9]))
print('An epsilon-greedy explore/exploit action:',q_learner.act([9,9,1,1,9]))
print('An epsilon-greedy explore/exploit action:',q_learner.act([9,9,1,1,9]))
print('An epsilon-greedy explore/exploit action:',q_learner.act([9,9,1,1,9]))
# Out:
# An epsilon-first action: 0
# An epsilon-first action: -1
# An epsilon-first action: 1
# An epsilon-greedy explore/exploit action: -1
# An epsilon-greedy explore/exploit action: -1
# An epsilon-greedy explore/exploit action: -1
# An epsilon-greedy explore/exploit action: 1
# An epsilon-greedy explore/exploit action: 1
# An epsilon-greedy explore/exploit action: -1
# An epsilon-greedy explore/exploit action: -1
# An epsilon-greedy explore/exploit action: -1
# An epsilon-greedy explore/exploit action: 0
# An epsilon-greedy explore/exploit action: -1
# An epsilon-greedy explore/exploit action: -1
# An epsilon-greedy explore/exploit action: -1

# %% [markdown]
# <a id='section8'></a>

# %% [markdown]
# ## Training

# %% [markdown]
# Now that all of your components work, you can try training your algorithm.  Do this by giving your `q_learner` as a player to a new `pong.PongGame` object.  Set `visibility=False` so that the `PongGame` doesn't create a new window.

# %%
import pong, importlib, submitted
importlib.reload(pong)
help(pong.PongGame.__init__)
# Out:
# Help on function __init__ in module pong:
#
# __init__(self, ball_speed=4, paddle_speed=8, learner=None, visible=True, state_quantization=[10, 10, 2, 2, 10])
#     Create a new pong game, with a specified player.
#
#     @params:
#     ball_speed (scalar int) - average ball speed in pixels/frame
#     paddle_speed (scalar int) - paddle moves 0, +paddle_speed, or -paddle_speed
#     learner - can be None if the player is human.  If not None, should be an
#       object of type random_learner, submitted.q_learner, or submitted.deep_q.
#     visible (bool) - should this game have an attached pygame window?
#     state_quantization (list) - if not None, state variables are quantized
#       into integers of these cardinalities before being passed to the learner.

# %% [markdown]
# As you can see, we should set `visibility=False` so that the `PongGame` doesn't create a new window.  We should also make sure that the PongGame uses the same state quantization as the learner.

# %%
importlib.reload(pong)
importlib.reload(submitted)
state_quantization = [10,10,2,2,10]
q_learner=submitted.q_learner(0.05,0.05,0.99,5,state_quantization)

pong_game = pong.PongGame(learner=q_learner, visible=False, state_quantization=state_quantization)
print(pong_game)
# Out:
# <pong.PongGame object at 0x7f9f30276160>

# %% [markdown]
# In order to train our learner, we want it to play the game many times.  To do that we use the PongGame.run function:

# %%
help(pong_game.run)
# Out:
# Help on method run in module pong:
#
# run(m_rewards=inf, m_games=inf, m_frames=inf, states=[]) method of pong.PongGame instance
#     Run the game.
#     @param
#     m_frames (scalar int): maximum number of frames to be played
#     m_rewards (scalar int): maximum number of rewards earned (+ or -)
#     m_games (scalar int): maximum number of games
#     states (list): list of states whose Q-values should be returned
#        each state is a list of 5 ints: ball_x, ball_y, ball_vx, ball_vy, paddle_y.
#        These are the (x,y) position of the ball, the (vx,vy) velocity of the ball,
#        and the y-position of the paddle, all quantized.
#        0 <= state[i] < state_cardinality[i], for all i in [0,4].
#
#
#     @return
#     scores (list): list of scores of all completed games
#
#     The following will be returned only if the player is q_learning or deep_q.
#     New elements will be added to these lists once/frame if m_frames is specified,
#     else once/reward if m_rewards is specified, else once/game:
#       q_achieved (list): list of the q-values of the moves that were taken
#       q_states (list): list of the q-values of requested states

# %% [markdown]
# In order to make sure our learner is learning, let's tell `pong_game.run` to output all 3 Q-values of all of the 4000 states in every time step.
#
# To make sure that's not an outrageous amount of data, let's tell it to only output the Q values once/reward, and ask it to only collect 5000 rewards:

# %%
states = [[x,y,vx,vy,py] for x in range(10) for y in range(10) for vx in range(2) for vy in range(2) for py in range(10) ]

scores, q_achieved, q_states = pong_game.run(m_rewards=500, states=states)

print('The number of games played was',len(scores))
print('The number of rewards was',len(q_states))
print('The size of each returned Q-matrix was',q_states[0].shape)
# Out:
# Completed 0 games, 1 rewards, 255 frames, score 0, max score 0
# Completed 1 games, 2 rewards, 463 frames, score 0, max score 0
# Completed 2 games, 3 rewards, 717 frames, score 0, max score 0
# Completed 3 games, 6 rewards, 1269 frames, score 2, max score 2
# Completed 4 games, 7 rewards, 1450 frames, score 0, max score 2
# Completed 5 games, 8 rewards, 1631 frames, score 0, max score 2
# Completed 6 games, 9 rewards, 1812 frames, score 0, max score 2
# Completed 7 games, 11 rewards, 2363 frames, score 1, max score 2
# Completed 8 games, 12 rewards, 2544 frames, score 0, max score 2
# Completed 9 games, 18 rewards, 3668 frames, score 5, max score 5
# Completed 10 games, 20 rewards, 4151 frames, score 1, max score 5
# Completed 11 games, 21 rewards, 4332 frames, score 0, max score 5
# Completed 12 games, 22 rewards, 4586 frames, score 0, max score 5
# Completed 13 games, 24 rewards, 5176 frames, score 1, max score 5
# Completed 14 games, 25 rewards, 5384 frames, score 0, max score 5
# Completed 15 games, 26 rewards, 5565 frames, score 0, max score 5
# Completed 16 games, 29 rewards, 6522 frames, score 2, max score 5
# Completed 17 games, 30 rewards, 6776 frames, score 0, max score 5
# Completed 18 games, 31 rewards, 6957 frames, score 0, max score 5
# Completed 19 games, 32 rewards, 7165 frames, score 0, max score 5
# Completed 20 games, 33 rewards, 7419 frames, score 0, max score 5
# Completed 21 games, 34 rewards, 7673 frames, score 0, max score 5
# Completed 22 games, 35 rewards, 7927 frames, score 0, max score 5
# Completed 23 games, 36 rewards, 8181 frames, score 0, max score 5
# Completed 24 games, 37 rewards, 8435 frames, score 0, max score 5
# Completed 25 games, 39 rewards, 9097 frames, score 1, max score 5
# Completed 26 games, 40 rewards, 9305 frames, score 0, max score 5
# Completed 27 games, 41 rewards, 9559 frames, score 0, max score 5
# Completed 28 games, 42 rewards, 9740 frames, score 0, max score 5
# Completed 29 games, 43 rewards, 9921 frames, score 0, max score 5
# Completed 30 games, 44 rewards, 10175 frames, score 0, max score 5
# Completed 31 games, 45 rewards, 10429 frames, score 0, max score 5
# Completed 32 games, 46 rewards, 10637 frames, score 0, max score 5
# Completed 33 games, 47 rewards, 10818 frames, score 0, max score 5
# Completed 34 games, 48 rewards, 11026 frames, score 0, max score 5
# Completed 35 games, 49 rewards, 11280 frames, score 0, max score 5
# Completed 36 games, 50 rewards, 11534 frames, score 0, max score 5
# Completed 37 games, 51 rewards, 11715 frames, score 0, max score 5
# Completed 38 games, 52 rewards, 11896 frames, score 0, max score 5
# Completed 39 games, 54 rewards, 12450 frames, score 1, max score 5
# Completed 40 games, 55 rewards, 12704 frames, score 0, max score 5
# Completed 41 games, 56 rewards, 12958 frames, score 0, max score 5
# Completed 42 games, 58 rewards, 13395 frames, score 1, max score 5
# Completed 43 games, 59 rewards, 13576 frames, score 0, max score 5
# Completed 44 games, 60 rewards, 13784 frames, score 0, max score 5
# Completed 45 games, 62 rewards, 14152 frames, score 1, max score 5
# Completed 46 games, 63 rewards, 14360 frames, score 0, max score 5
# Completed 47 games, 64 rewards, 14568 frames, score 0, max score 5
# Completed 48 games, 65 rewards, 14749 frames, score 0, max score 5
# Completed 49 games, 66 rewards, 14930 frames, score 0, max score 5
# Completed 50 games, 68 rewards, 15367 frames, score 1, max score 5
# Completed 51 games, 69 rewards, 15621 frames, score 0, max score 5
# Completed 52 games, 74 rewards, 16958 frames, score 4, max score 5
# Completed 53 games, 75 rewards, 17212 frames, score 0, max score 5
# Completed 54 games, 76 rewards, 17393 frames, score 0, max score 5
# Completed 55 games, 77 rewards, 17647 frames, score 0, max score 5
# Completed 56 games, 78 rewards, 17901 frames, score 0, max score 5
# Completed 57 games, 79 rewards, 18155 frames, score 0, max score 5
# Completed 58 games, 80 rewards, 18363 frames, score 0, max score 5
# Completed 59 games, 81 rewards, 18617 frames, score 0, max score 5
# Completed 60 games, 82 rewards, 18798 frames, score 0, max score 5
# Completed 61 games, 83 rewards, 18979 frames, score 0, max score 5
# Completed 62 games, 84 rewards, 19187 frames, score 0, max score 5
# Completed 63 games, 85 rewards, 19395 frames, score 0, max score 5
# Completed 64 games, 87 rewards, 19892 frames, score 1, max score 5
# Completed 65 games, 90 rewards, 21916 frames, score 2, max score 5
# Completed 66 games, 92 rewards, 22578 frames, score 1, max score 5
# Completed 67 games, 93 rewards, 22832 frames, score 0, max score 5
# Completed 68 games, 94 rewards, 23013 frames, score 0, max score 5
# Completed 69 games, 95 rewards, 23267 frames, score 0, max score 5
# Completed 70 games, 97 rewards, 23619 frames, score 1, max score 5
# Completed 71 games, 99 rewards, 24047 frames, score 1, max score 5
# Completed 72 games, 102 rewards, 24756 frames, score 2, max score 5
# Completed 73 games, 104 rewards, 25219 frames, score 1, max score 5
# Completed 74 games, 105 rewards, 25427 frames, score 0, max score 5
# Completed 75 games, 107 rewards, 25832 frames, score 1, max score 5
# Completed 76 games, 108 rewards, 26040 frames, score 0, max score 5
# Completed 77 games, 109 rewards, 26221 frames, score 0, max score 5
# Completed 78 games, 112 rewards, 26942 frames, score 2, max score 5
# Completed 79 games, 116 rewards, 28053 frames, score 3, max score 5
# Completed 80 games, 117 rewards, 28234 frames, score 0, max score 5
# Completed 81 games, 118 rewards, 28442 frames, score 0, max score 5
# Completed 82 games, 126 rewards, 30588 frames, score 7, max score 7
# Completed 83 games, 129 rewards, 31314 frames, score 2, max score 7
# Completed 84 games, 131 rewards, 31777 frames, score 1, max score 7
# Completed 85 games, 132 rewards, 32031 frames, score 0, max score 7
# Completed 86 games, 133 rewards, 32285 frames, score 0, max score 7
# Completed 87 games, 134 rewards, 32466 frames, score 0, max score 7
# Completed 88 games, 136 rewards, 32903 frames, score 1, max score 7
# Completed 89 games, 139 rewards, 33751 frames, score 2, max score 7
# Completed 90 games, 141 rewards, 34263 frames, score 1, max score 7
# Completed 91 games, 142 rewards, 34471 frames, score 0, max score 7
# Completed 92 games, 143 rewards, 34652 frames, score 0, max score 7
# Completed 93 games, 144 rewards, 34833 frames, score 0, max score 7
# Completed 94 games, 145 rewards, 35041 frames, score 0, max score 7
# Completed 95 games, 147 rewards, 35529 frames, score 1, max score 7
# Completed 96 games, 149 rewards, 36000 frames, score 1, max score 7
# Completed 97 games, 151 rewards, 36368 frames, score 1, max score 7
# Completed 98 games, 154 rewards, 37004 frames, score 2, max score 7
# Completed 99 games, 156 rewards, 37410 frames, score 1, max score 7
# Completed 100 games, 159 rewards, 38067 frames, score 2, max score 7
# Completed 101 games, 160 rewards, 38321 frames, score 0, max score 7
# Completed 102 games, 163 rewards, 39300 frames, score 2, max score 7
# Completed 103 games, 164 rewards, 39508 frames, score 0, max score 7
# Completed 104 games, 165 rewards, 39716 frames, score 0, max score 7
# Completed 105 games, 166 rewards, 39897 frames, score 0, max score 7
# Completed 106 games, 167 rewards, 40105 frames, score 0, max score 7
# Completed 107 games, 168 rewards, 40313 frames, score 0, max score 7
# Completed 108 games, 169 rewards, 40494 frames, score 0, max score 7
# Completed 109 games, 172 rewards, 41047 frames, score 2, max score 7
# Completed 110 games, 175 rewards, 41601 frames, score 2, max score 7
# Completed 111 games, 176 rewards, 41809 frames, score 0, max score 7
# Completed 112 games, 177 rewards, 41990 frames, score 0, max score 7
# Completed 113 games, 180 rewards, 42525 frames, score 2, max score 7
# Completed 114 games, 182 rewards, 42931 frames, score 1, max score 7
# Completed 115 games, 183 rewards, 43112 frames, score 0, max score 7
# Completed 116 games, 185 rewards, 43479 frames, score 1, max score 7
# Completed 117 games, 191 rewards, 44598 frames, score 5, max score 7
# Completed 118 games, 192 rewards, 44806 frames, score 0, max score 7
# Completed 119 games, 193 rewards, 45014 frames, score 0, max score 7
# Completed 120 games, 194 rewards, 45222 frames, score 0, max score 7
# Completed 121 games, 195 rewards, 45430 frames, score 0, max score 7
# Completed 122 games, 198 rewards, 45984 frames, score 2, max score 7
# Completed 123 games, 200 rewards, 46352 frames, score 1, max score 7
# Completed 124 games, 201 rewards, 46560 frames, score 0, max score 7
# Completed 125 games, 203 rewards, 47111 frames, score 1, max score 7
# Completed 126 games, 206 rewards, 47611 frames, score 2, max score 7
# Completed 127 games, 207 rewards, 47792 frames, score 0, max score 7
# Completed 128 games, 208 rewards, 48000 frames, score 0, max score 7
# Completed 129 games, 212 rewards, 49091 frames, score 3, max score 7
# Completed 130 games, 213 rewards, 49272 frames, score 0, max score 7
# Completed 131 games, 214 rewards, 49480 frames, score 0, max score 7
# Completed 132 games, 215 rewards, 49688 frames, score 0, max score 7
# Completed 133 games, 218 rewards, 51196 frames, score 2, max score 7
# Completed 134 games, 219 rewards, 51377 frames, score 0, max score 7
# Completed 135 games, 220 rewards, 51585 frames, score 0, max score 7
# Completed 136 games, 222 rewards, 52247 frames, score 1, max score 7
# Completed 137 games, 223 rewards, 52428 frames, score 0, max score 7
# Completed 138 games, 226 rewards, 53081 frames, score 2, max score 7
# Completed 139 games, 227 rewards, 53262 frames, score 0, max score 7
# Completed 140 games, 228 rewards, 53470 frames, score 0, max score 7
# Completed 141 games, 229 rewards, 53651 frames, score 0, max score 7
# Completed 142 games, 231 rewards, 54202 frames, score 1, max score 7
# Completed 143 games, 234 rewards, 54822 frames, score 2, max score 7
# Completed 144 games, 235 rewards, 55076 frames, score 0, max score 7
# Completed 145 games, 236 rewards, 55257 frames, score 0, max score 7
# Completed 146 games, 237 rewards, 55465 frames, score 0, max score 7
# Completed 147 games, 238 rewards, 55646 frames, score 0, max score 7
# Completed 148 games, 240 rewards, 56565 frames, score 1, max score 7
# Completed 149 games, 241 rewards, 56773 frames, score 0, max score 7
# Completed 150 games, 242 rewards, 57027 frames, score 0, max score 7
# Completed 151 games, 245 rewards, 57566 frames, score 2, max score 7
# Completed 152 games, 246 rewards, 57820 frames, score 0, max score 7
# Completed 153 games, 247 rewards, 58001 frames, score 0, max score 7
# Completed 154 games, 250 rewards, 59026 frames, score 2, max score 7
# Completed 155 games, 254 rewards, 60024 frames, score 3, max score 7
# Completed 156 games, 256 rewards, 60626 frames, score 1, max score 7
# Completed 157 games, 257 rewards, 60807 frames, score 0, max score 7
# Completed 158 games, 258 rewards, 60988 frames, score 0, max score 7
# Completed 159 games, 261 rewards, 61514 frames, score 2, max score 7
# Completed 160 games, 263 rewards, 62433 frames, score 1, max score 7
# Completed 161 games, 264 rewards, 62641 frames, score 0, max score 7
# Completed 162 games, 265 rewards, 62822 frames, score 0, max score 7
# Completed 163 games, 268 rewards, 63519 frames, score 2, max score 7
# Completed 164 games, 270 rewards, 63871 frames, score 1, max score 7
# Completed 165 games, 271 rewards, 64079 frames, score 0, max score 7
# Completed 166 games, 277 rewards, 65857 frames, score 5, max score 7
# Completed 167 games, 278 rewards, 66038 frames, score 0, max score 7
# Completed 168 games, 279 rewards, 66219 frames, score 0, max score 7
# Completed 169 games, 283 rewards, 67639 frames, score 3, max score 7
# Completed 170 games, 284 rewards, 67820 frames, score 0, max score 7
# Completed 171 games, 286 rewards, 68554 frames, score 1, max score 7
# Completed 172 games, 287 rewards, 68735 frames, score 0, max score 7
# Completed 173 games, 288 rewards, 68916 frames, score 0, max score 7
# Completed 174 games, 290 rewards, 69578 frames, score 1, max score 7
# Completed 175 games, 294 rewards, 70309 frames, score 3, max score 7
# Completed 176 games, 295 rewards, 70490 frames, score 0, max score 7
# Completed 177 games, 298 rewards, 71599 frames, score 2, max score 7
# Completed 178 games, 299 rewards, 71807 frames, score 0, max score 7
# Completed 179 games, 300 rewards, 71988 frames, score 0, max score 7
# Completed 180 games, 302 rewards, 72539 frames, score 1, max score 7
# Completed 181 games, 303 rewards, 72793 frames, score 0, max score 7
# Completed 182 games, 305 rewards, 73256 frames, score 1, max score 7
# Completed 183 games, 307 rewards, 73623 frames, score 1, max score 7
# Completed 184 games, 308 rewards, 73831 frames, score 0, max score 7
# Completed 185 games, 311 rewards, 74609 frames, score 2, max score 7
# Completed 186 games, 312 rewards, 74817 frames, score 0, max score 7
# Completed 187 games, 313 rewards, 75025 frames, score 0, max score 7
# Completed 188 games, 314 rewards, 75233 frames, score 0, max score 7
# Completed 189 games, 316 rewards, 75631 frames, score 1, max score 7
# Completed 190 games, 320 rewards, 76356 frames, score 3, max score 7
# Completed 191 games, 321 rewards, 76610 frames, score 0, max score 7
# Completed 192 games, 322 rewards, 76864 frames, score 0, max score 7
# Completed 193 games, 324 rewards, 77466 frames, score 1, max score 7
# Completed 194 games, 326 rewards, 77807 frames, score 1, max score 7
# Completed 195 games, 329 rewards, 78314 frames, score 2, max score 7
# Completed 196 games, 331 rewards, 78697 frames, score 1, max score 7
# Completed 197 games, 332 rewards, 78878 frames, score 0, max score 7
# Completed 198 games, 339 rewards, 80418 frames, score 6, max score 7
# Completed 199 games, 341 rewards, 80915 frames, score 1, max score 7
# Completed 200 games, 342 rewards, 81169 frames, score 0, max score 7
# Completed 201 games, 343 rewards, 81377 frames, score 0, max score 7
# Completed 202 games, 344 rewards, 81631 frames, score 0, max score 7
# Completed 203 games, 346 rewards, 81999 frames, score 1, max score 7
# Completed 204 games, 347 rewards, 82207 frames, score 0, max score 7
# Completed 205 games, 351 rewards, 84634 frames, score 3, max score 7
# Completed 206 games, 352 rewards, 84815 frames, score 0, max score 7
# Completed 207 games, 353 rewards, 84996 frames, score 0, max score 7
# Completed 208 games, 354 rewards, 85177 frames, score 0, max score 7
# Completed 209 games, 361 rewards, 86600 frames, score 6, max score 7
# Completed 210 games, 364 rewards, 87091 frames, score 2, max score 7
# Completed 211 games, 366 rewards, 87588 frames, score 1, max score 7
# Completed 212 games, 367 rewards, 87769 frames, score 0, max score 7
# Completed 213 games, 369 rewards, 88197 frames, score 1, max score 7
# Completed 214 games, 370 rewards, 88378 frames, score 0, max score 7
# Completed 215 games, 373 rewards, 88918 frames, score 2, max score 7
# Completed 216 games, 374 rewards, 89172 frames, score 0, max score 7
# Completed 217 games, 376 rewards, 89577 frames, score 1, max score 7
# Completed 218 games, 377 rewards, 89831 frames, score 0, max score 7
# Completed 219 games, 379 rewards, 90229 frames, score 1, max score 7
# Completed 220 games, 381 rewards, 90780 frames, score 1, max score 7
# Completed 221 games, 383 rewards, 91148 frames, score 1, max score 7
# Completed 222 games, 390 rewards, 94528 frames, score 6, max score 7
# Completed 223 games, 391 rewards, 94709 frames, score 0, max score 7
# Completed 224 games, 392 rewards, 94963 frames, score 0, max score 7
# Completed 225 games, 393 rewards, 95171 frames, score 0, max score 7
# Completed 226 games, 398 rewards, 96152 frames, score 4, max score 7
# Completed 227 games, 399 rewards, 96333 frames, score 0, max score 7
# Completed 228 games, 400 rewards, 96514 frames, score 0, max score 7
# Completed 229 games, 402 rewards, 96855 frames, score 1, max score 7
# Completed 230 games, 405 rewards, 98027 frames, score 2, max score 7
# Completed 231 games, 410 rewards, 98997 frames, score 4, max score 7
# Completed 232 games, 411 rewards, 99251 frames, score 0, max score 7
# Completed 233 games, 412 rewards, 99505 frames, score 0, max score 7
# Completed 234 games, 414 rewards, 99942 frames, score 1, max score 7
# Completed 235 games, 415 rewards, 100123 frames, score 0, max score 7
# Completed 236 games, 418 rewards, 100949 frames, score 2, max score 7
# Completed 237 games, 420 rewards, 101551 frames, score 1, max score 7
# Completed 238 games, 421 rewards, 101805 frames, score 0, max score 7
# Completed 239 games, 422 rewards, 101986 frames, score 0, max score 7
# Completed 240 games, 424 rewards, 102338 frames, score 1, max score 7
# Completed 241 games, 425 rewards, 102519 frames, score 0, max score 7
# Completed 242 games, 426 rewards, 102700 frames, score 0, max score 7
# Completed 243 games, 427 rewards, 102908 frames, score 0, max score 7
# Completed 244 games, 428 rewards, 103162 frames, score 0, max score 7
# Completed 245 games, 429 rewards, 103370 frames, score 0, max score 7
# Completed 246 games, 435 rewards, 104511 frames, score 5, max score 7
# Completed 247 games, 436 rewards, 104719 frames, score 0, max score 7
# Completed 248 games, 438 rewards, 105173 frames, score 1, max score 7
# Completed 249 games, 439 rewards, 105427 frames, score 0, max score 7
# Completed 250 games, 440 rewards, 105681 frames, score 0, max score 7
# Completed 251 games, 443 rewards, 106328 frames, score 2, max score 7
# Completed 252 games, 450 rewards, 108444 frames, score 6, max score 7
# Completed 253 games, 451 rewards, 108625 frames, score 0, max score 7
# Completed 254 games, 452 rewards, 108879 frames, score 0, max score 7
# Completed 255 games, 453 rewards, 109060 frames, score 0, max score 7
# Completed 256 games, 454 rewards, 109268 frames, score 0, max score 7
# Completed 257 games, 456 rewards, 109731 frames, score 1, max score 7
# Completed 258 games, 457 rewards, 109912 frames, score 0, max score 7
# Completed 259 games, 459 rewards, 110253 frames, score 1, max score 7
# Completed 260 games, 460 rewards, 110434 frames, score 0, max score 7
# Completed 261 games, 461 rewards, 110642 frames, score 0, max score 7
# Completed 262 games, 462 rewards, 110823 frames, score 0, max score 7
# Completed 263 games, 464 rewards, 111206 frames, score 1, max score 7
# Completed 264 games, 465 rewards, 111387 frames, score 0, max score 7
# Completed 265 games, 468 rewards, 112405 frames, score 2, max score 7
# Completed 266 games, 473 rewards, 113287 frames, score 4, max score 7
# Completed 267 games, 477 rewards, 114675 frames, score 3, max score 7
# Completed 268 games, 478 rewards, 114883 frames, score 0, max score 7
# Completed 269 games, 479 rewards, 115137 frames, score 0, max score 7
# Completed 270 games, 481 rewards, 115739 frames, score 1, max score 7
# Completed 271 games, 484 rewards, 116278 frames, score 2, max score 7
# Completed 272 games, 485 rewards, 116486 frames, score 0, max score 7
# Completed 273 games, 486 rewards, 116667 frames, score 0, max score 7
# Completed 274 games, 487 rewards, 116848 frames, score 0, max score 7
# Completed 275 games, 488 rewards, 117056 frames, score 0, max score 7
# Completed 276 games, 489 rewards, 117264 frames, score 0, max score 7
# Completed 277 games, 491 rewards, 117776 frames, score 1, max score 7
# Completed 278 games, 492 rewards, 117957 frames, score 0, max score 7
# Completed 279 games, 493 rewards, 118211 frames, score 0, max score 7
# Completed 280 games, 494 rewards, 118392 frames, score 0, max score 7
# Completed 281 games, 496 rewards, 118759 frames, score 1, max score 7
# Completed 282 games, 499 rewards, 119374 frames, score 2, max score 7
# Completed 283 games, 500 rewards, 119555 frames, score 0, max score 7
# The number of games played was 285
# The number of rewards was 500
# The size of each returned Q-matrix was (4000, 3)

# %% [markdown]
# The returned value of `q_states` is a list of 4000x3 numpy arrays (20 states, 3 actions).  The list contains `m_rewards` of these. We want to convert it into something that matplotlib can plot.

# %%
import numpy as np

Q = np.array([np.reshape(q,-1) for q in q_states])
print('Q is now of shape',Q.shape)
print('the max absolute value of Q is ',np.amax(abs(Q)))
# Out:
# Q is now of shape (500, 12000)
# the max absolute value of Q is  2.1372232590650677

# %%
# %matplotlib inline

import matplotlib.pyplot as plt

fig = plt.figure(figsize=(14,6),layout='tight')
ax = [ fig.add_subplot(2,1,x) for x in range(1,3) ]
ax[0].plot(np.arange(0,len(q_states)),Q)
ax[0].set_title('Q values of all states')
ax[1].plot(np.arange(0,len(q_states)),q_achieved)
ax[1].set_title('Q values of state achieved at each time')
ax[1].set_ylabel('Reward number')
# Out:
# Text(0, 0.5, 'Reward number')

# %% [markdown]
# OK, now let's try running it for a much longer period -- say, 5000 complete games.  We won't ask it to print out any states this time.

# %%
scores, q_achieved, q_states = pong_game.run(m_games=5000, states=[])

print('The number of games played was',len(scores))
print('The number of video frames was',len(q_states))
print('The size of each returned Q-matrix was',q_states[0].shape)
# Out:
# Completed 0 games, 1 rewards, 255 frames, score 0, max score 7
# Completed 1 games, 4 rewards, 1085 frames, score 2, max score 7
# Completed 2 games, 10 rewards, 2629 frames, score 5, max score 7
# Completed 3 games, 11 rewards, 2810 frames, score 0, max score 7
# Completed 4 games, 13 rewards, 3247 frames, score 1, max score 7
# Completed 5 games, 16 rewards, 4205 frames, score 2, max score 7
# Completed 6 games, 18 rewards, 4557 frames, score 1, max score 7
# Completed 7 games, 21 rewards, 5207 frames, score 2, max score 7
# Completed 8 games, 22 rewards, 5415 frames, score 0, max score 7
# Completed 9 games, 23 rewards, 5669 frames, score 0, max score 7
# Completed 10 games, 24 rewards, 5923 frames, score 0, max score 7
# Completed 11 games, 27 rewards, 6652 frames, score 2, max score 7
# Completed 12 games, 30 rewards, 7278 frames, score 2, max score 7
# Completed 13 games, 32 rewards, 7868 frames, score 1, max score 7
# Completed 14 games, 35 rewards, 8667 frames, score 2, max score 7
# Completed 15 games, 37 rewards, 9155 frames, score 1, max score 7
# Completed 16 games, 38 rewards, 9336 frames, score 0, max score 7
# Completed 17 games, 39 rewards, 9544 frames, score 0, max score 7
# Completed 18 games, 41 rewards, 9972 frames, score 1, max score 7
# Completed 19 games, 42 rewards, 10180 frames, score 0, max score 7
# Completed 20 games, 47 rewards, 12827 frames, score 4, max score 7
# Completed 21 games, 48 rewards, 13035 frames, score 0, max score 7
# Completed 22 games, 50 rewards, 13495 frames, score 1, max score 7
# Completed 23 games, 52 rewards, 13878 frames, score 1, max score 7
# Completed 24 games, 54 rewards, 14751 frames, score 1, max score 7
# Completed 25 games, 56 rewards, 15341 frames, score 1, max score 7
# Completed 26 games, 57 rewards, 15595 frames, score 0, max score 7
# Completed 27 games, 61 rewards, 16294 frames, score 3, max score 7
# Completed 28 games, 62 rewards, 16502 frames, score 0, max score 7
# Completed 29 games, 67 rewards, 17530 frames, score 4, max score 7
# Completed 30 games, 72 rewards, 19004 frames, score 4, max score 7
# Completed 31 games, 76 rewards, 20439 frames, score 3, max score 7
# Completed 32 games, 82 rewards, 21702 frames, score 5, max score 7
# Completed 33 games, 85 rewards, 22803 frames, score 2, max score 7
# Completed 34 games, 88 rewards, 23367 frames, score 2, max score 7
# Completed 35 games, 89 rewards, 23621 frames, score 0, max score 7
# Completed 36 games, 90 rewards, 23875 frames, score 0, max score 7
# Completed 37 games, 93 rewards, 24507 frames, score 2, max score 7
# Completed 38 games, 94 rewards, 24688 frames, score 0, max score 7
# Completed 39 games, 95 rewards, 24869 frames, score 0, max score 7
# Completed 40 games, 96 rewards, 25077 frames, score 0, max score 7
# Completed 41 games, 98 rewards, 25667 frames, score 1, max score 7
# Completed 42 games, 99 rewards, 25921 frames, score 0, max score 7
# Completed 43 games, 100 rewards, 26102 frames, score 0, max score 7
# Completed 44 games, 102 rewards, 26836 frames, score 1, max score 7
# Completed 45 games, 105 rewards, 27422 frames, score 2, max score 7
# Completed 46 games, 106 rewards, 27630 frames, score 0, max score 7
# Completed 47 games, 107 rewards, 27838 frames, score 0, max score 7
# Completed 48 games, 108 rewards, 28019 frames, score 0, max score 7
# Completed 49 games, 110 rewards, 28482 frames, score 1, max score 7
# Completed 50 games, 111 rewards, 28736 frames, score 0, max score 7
# Completed 51 games, 112 rewards, 28917 frames, score 0, max score 7
# Completed 52 games, 113 rewards, 29125 frames, score 0, max score 7
# Completed 53 games, 115 rewards, 29643 frames, score 1, max score 7
# Completed 54 games, 119 rewards, 30847 frames, score 3, max score 7
# Completed 55 games, 122 rewards, 32540 frames, score 2, max score 7
# Completed 56 games, 123 rewards, 32748 frames, score 0, max score 7
# Completed 57 games, 124 rewards, 32929 frames, score 0, max score 7
# Completed 58 games, 127 rewards, 33436 frames, score 2, max score 7
# Completed 59 games, 128 rewards, 33617 frames, score 0, max score 7
# Completed 60 games, 129 rewards, 33871 frames, score 0, max score 7
# Completed 61 games, 131 rewards, 34277 frames, score 1, max score 7
# Completed 62 games, 132 rewards, 34531 frames, score 0, max score 7
# Completed 63 games, 139 rewards, 35709 frames, score 6, max score 7
# Completed 64 games, 140 rewards, 35890 frames, score 0, max score 7
# Completed 65 games, 142 rewards, 36506 frames, score 1, max score 7
# Completed 66 games, 143 rewards, 36714 frames, score 0, max score 7
# Completed 67 games, 144 rewards, 36968 frames, score 0, max score 7
# Completed 68 games, 147 rewards, 38992 frames, score 2, max score 7
# Completed 69 games, 148 rewards, 39173 frames, score 0, max score 7
# Completed 70 games, 153 rewards, 39997 frames, score 4, max score 7
# Completed 71 games, 156 rewards, 40724 frames, score 2, max score 7
# Completed 72 games, 157 rewards, 40905 frames, score 0, max score 7
# Completed 73 games, 158 rewards, 41113 frames, score 0, max score 7
# Completed 74 games, 159 rewards, 41367 frames, score 0, max score 7
# Completed 75 games, 160 rewards, 41548 frames, score 0, max score 7
# Completed 76 games, 163 rewards, 42178 frames, score 2, max score 7
# Completed 77 games, 164 rewards, 42386 frames, score 0, max score 7
# Completed 78 games, 165 rewards, 42594 frames, score 0, max score 7
# Completed 79 games, 166 rewards, 42848 frames, score 0, max score 7
# Completed 80 games, 167 rewards, 43056 frames, score 0, max score 7
# Completed 81 games, 169 rewards, 43790 frames, score 1, max score 7
# Completed 82 games, 170 rewards, 44044 frames, score 0, max score 7
# Completed 83 games, 171 rewards, 44298 frames, score 0, max score 7
# Completed 84 games, 173 rewards, 45217 frames, score 1, max score 7
# Completed 85 games, 175 rewards, 45768 frames, score 1, max score 7
# Completed 86 games, 176 rewards, 46022 frames, score 0, max score 7
# Completed 87 games, 183 rewards, 47932 frames, score 6, max score 7
# Completed 88 games, 185 rewards, 48299 frames, score 1, max score 7
# Completed 89 games, 186 rewards, 48553 frames, score 0, max score 7
# Completed 90 games, 188 rewards, 49169 frames, score 1, max score 7
# Completed 91 games, 189 rewards, 49377 frames, score 0, max score 7
# Completed 92 games, 190 rewards, 49558 frames, score 0, max score 7
# Completed 93 games, 191 rewards, 49766 frames, score 0, max score 7
# Completed 94 games, 193 rewards, 50229 frames, score 1, max score 7
# Completed 95 games, 195 rewards, 50718 frames, score 1, max score 7
# Completed 96 games, 196 rewards, 50972 frames, score 0, max score 7
# Completed 97 games, 198 rewards, 51339 frames, score 1, max score 7
# Completed 98 games, 199 rewards, 51547 frames, score 0, max score 7
# Completed 99 games, 204 rewards, 52481 frames, score 4, max score 7
# Completed 100 games, 205 rewards, 52735 frames, score 0, max score 7
# Completed 101 games, 210 rewards, 53764 frames, score 4, max score 7
# Completed 102 games, 211 rewards, 54018 frames, score 0, max score 7
# Completed 103 games, 213 rewards, 54891 frames, score 1, max score 7
# Completed 104 games, 214 rewards, 55072 frames, score 0, max score 7
# Completed 105 games, 215 rewards, 55253 frames, score 0, max score 7
# Completed 106 games, 218 rewards, 55781 frames, score 2, max score 7
# Completed 107 games, 221 rewards, 56667 frames, score 2, max score 7
# Completed 108 games, 223 rewards, 57586 frames, score 1, max score 7
# Completed 109 games, 224 rewards, 57794 frames, score 0, max score 7
# Completed 110 games, 228 rewards, 58438 frames, score 3, max score 7
# Completed 111 games, 229 rewards, 58646 frames, score 0, max score 7
# Completed 112 games, 231 rewards, 59180 frames, score 1, max score 7
# Completed 113 games, 235 rewards, 60078 frames, score 3, max score 7
# Completed 114 games, 237 rewards, 60515 frames, score 1, max score 7
# Completed 115 games, 238 rewards, 60769 frames, score 0, max score 7
# Completed 116 games, 240 rewards, 61185 frames, score 1, max score 7
# Completed 117 games, 246 rewards, 63257 frames, score 5, max score 7
# Completed 118 games, 247 rewards, 63465 frames, score 0, max score 7
# Completed 119 games, 251 rewards, 64083 frames, score 3, max score 7
# Completed 120 games, 254 rewards, 64575 frames, score 2, max score 7
# Completed 121 games, 261 rewards, 67826 frames, score 6, max score 7
# Completed 122 games, 264 rewards, 68432 frames, score 2, max score 7
# Completed 123 games, 274 rewards, 70189 frames, score 9, max score 9
# Completed 124 games, 281 rewards, 71998 frames, score 6, max score 9
# Completed 125 games, 286 rewards, 72995 frames, score 4, max score 9
# Completed 126 games, 287 rewards, 73176 frames, score 0, max score 9
# Completed 127 games, 288 rewards, 73384 frames, score 0, max score 9
# Completed 128 games, 290 rewards, 73863 frames, score 1, max score 9
# Completed 129 games, 291 rewards, 74044 frames, score 0, max score 9
# Completed 130 games, 295 rewards, 75259 frames, score 3, max score 9
# Completed 131 games, 301 rewards, 76410 frames, score 5, max score 9
# Completed 132 games, 308 rewards, 80552 frames, score 6, max score 9
# Completed 133 games, 310 rewards, 80904 frames, score 1, max score 9
# Completed 134 games, 314 rewards, 82064 frames, score 3, max score 9
# Completed 135 games, 321 rewards, 83088 frames, score 6, max score 9
# Completed 136 games, 324 rewards, 83673 frames, score 2, max score 9
# Completed 137 games, 327 rewards, 84274 frames, score 2, max score 9
# Completed 138 games, 329 rewards, 84679 frames, score 1, max score 9
# Completed 139 games, 334 rewards, 85634 frames, score 4, max score 9
# Completed 140 games, 341 rewards, 87863 frames, score 6, max score 9
# Completed 141 games, 342 rewards, 88071 frames, score 0, max score 9
# Completed 142 games, 344 rewards, 88454 frames, score 1, max score 9
# Completed 143 games, 346 rewards, 88891 frames, score 1, max score 9
# Completed 144 games, 347 rewards, 89145 frames, score 0, max score 9
# Completed 145 games, 348 rewards, 89326 frames, score 0, max score 9
# Completed 146 games, 349 rewards, 89507 frames, score 0, max score 9
# Completed 147 games, 350 rewards, 89715 frames, score 0, max score 9
# Completed 148 games, 353 rewards, 90538 frames, score 2, max score 9
# Completed 149 games, 355 rewards, 91035 frames, score 1, max score 9
# Completed 150 games, 356 rewards, 91216 frames, score 0, max score 9
# Completed 151 games, 357 rewards, 91397 frames, score 0, max score 9
# Completed 152 games, 358 rewards, 91605 frames, score 0, max score 9
# Completed 153 games, 359 rewards, 91813 frames, score 0, max score 9
# Completed 154 games, 360 rewards, 92067 frames, score 0, max score 9
# Completed 155 games, 363 rewards, 92936 frames, score 2, max score 9
# Completed 156 games, 365 rewards, 93399 frames, score 1, max score 9
# Completed 157 games, 367 rewards, 93950 frames, score 1, max score 9
# Completed 158 games, 369 rewards, 94458 frames, score 1, max score 9
# Completed 159 games, 370 rewards, 94666 frames, score 0, max score 9
# Completed 160 games, 371 rewards, 94847 frames, score 0, max score 9
# Completed 161 games, 372 rewards, 95028 frames, score 0, max score 9
# Completed 162 games, 373 rewards, 95282 frames, score 0, max score 9
# Completed 163 games, 378 rewards, 96982 frames, score 4, max score 9
# Completed 164 games, 381 rewards, 97505 frames, score 2, max score 9
# Completed 165 games, 384 rewards, 98390 frames, score 2, max score 9
# Completed 166 games, 386 rewards, 98788 frames, score 1, max score 9
# Completed 167 games, 387 rewards, 98996 frames, score 0, max score 9
# Completed 168 games, 388 rewards, 99204 frames, score 0, max score 9
# Completed 169 games, 390 rewards, 99748 frames, score 1, max score 9
# Completed 170 games, 394 rewards, 101765 frames, score 3, max score 9
# Completed 171 games, 397 rewards, 102808 frames, score 2, max score 9
# Completed 172 games, 399 rewards, 103206 frames, score 1, max score 9
# Completed 173 games, 400 rewards, 103460 frames, score 0, max score 9
# Completed 174 games, 402 rewards, 103870 frames, score 1, max score 9
# Completed 175 games, 403 rewards, 104124 frames, score 0, max score 9
# Completed 176 games, 406 rewards, 104869 frames, score 2, max score 9
# Completed 177 games, 410 rewards, 105710 frames, score 3, max score 9
# Completed 178 games, 412 rewards, 106189 frames, score 1, max score 9
# Completed 179 games, 413 rewards, 106397 frames, score 0, max score 9
# Completed 180 games, 414 rewards, 106578 frames, score 0, max score 9
# Completed 181 games, 419 rewards, 107897 frames, score 4, max score 9
# Completed 182 games, 420 rewards, 108078 frames, score 0, max score 9
# Completed 183 games, 421 rewards, 108259 frames, score 0, max score 9
# Completed 184 games, 422 rewards, 108440 frames, score 0, max score 9
# Completed 185 games, 425 rewards, 109030 frames, score 2, max score 9
# Completed 186 games, 426 rewards, 109211 frames, score 0, max score 9
# Completed 187 games, 427 rewards, 109419 frames, score 0, max score 9
# Completed 188 games, 431 rewards, 110081 frames, score 3, max score 9
# Completed 189 games, 433 rewards, 110431 frames, score 1, max score 9
# Completed 190 games, 434 rewards, 110639 frames, score 0, max score 9
# Completed 191 games, 436 rewards, 111301 frames, score 1, max score 9
# Completed 192 games, 438 rewards, 111699 frames, score 1, max score 9
# Completed 193 games, 439 rewards, 111907 frames, score 0, max score 9
# Completed 194 games, 441 rewards, 112259 frames, score 1, max score 9
# Completed 195 games, 444 rewards, 112758 frames, score 2, max score 9
# Completed 196 games, 446 rewards, 113270 frames, score 1, max score 9
# Completed 197 games, 447 rewards, 113524 frames, score 0, max score 9
# Completed 198 games, 448 rewards, 113705 frames, score 0, max score 9
# Completed 199 games, 450 rewards, 114624 frames, score 1, max score 9
# Completed 200 games, 451 rewards, 114878 frames, score 0, max score 9
# Completed 201 games, 452 rewards, 115059 frames, score 0, max score 9
# Completed 202 games, 453 rewards, 115240 frames, score 0, max score 9
# Completed 203 games, 454 rewards, 115448 frames, score 0, max score 9
# Completed 204 games, 455 rewards, 115702 frames, score 0, max score 9
# Completed 205 games, 458 rewards, 116359 frames, score 2, max score 9
# Completed 206 games, 459 rewards, 116613 frames, score 0, max score 9
# Completed 207 games, 460 rewards, 116867 frames, score 0, max score 9
# Completed 208 games, 466 rewards, 117890 frames, score 5, max score 9
# Completed 209 games, 469 rewards, 119424 frames, score 2, max score 9
# Completed 210 games, 470 rewards, 119632 frames, score 0, max score 9
# Completed 211 games, 471 rewards, 119886 frames, score 0, max score 9
# Completed 212 games, 474 rewards, 120825 frames, score 2, max score 9
# Completed 213 games, 475 rewards, 121006 frames, score 0, max score 9
# Completed 214 games, 476 rewards, 121260 frames, score 0, max score 9
# Completed 215 games, 478 rewards, 121720 frames, score 1, max score 9
# Completed 216 games, 479 rewards, 121974 frames, score 0, max score 9
# Completed 217 games, 480 rewards, 122228 frames, score 0, max score 9
# Completed 218 games, 481 rewards, 122436 frames, score 0, max score 9
# Completed 219 games, 482 rewards, 122617 frames, score 0, max score 9
# Completed 220 games, 484 rewards, 123023 frames, score 1, max score 9
# Completed 221 games, 486 rewards, 123390 frames, score 1, max score 9
# Completed 222 games, 487 rewards, 123571 frames, score 0, max score 9
# Completed 223 games, 489 rewards, 124173 frames, score 1, max score 9
# Completed 224 games, 490 rewards, 124381 frames, score 0, max score 9
# Completed 225 games, 495 rewards, 125667 frames, score 4, max score 9
# Completed 226 games, 496 rewards, 125848 frames, score 0, max score 9
# Completed 227 games, 497 rewards, 126056 frames, score 0, max score 9
# Completed 228 games, 498 rewards, 126237 frames, score 0, max score 9
# Completed 229 games, 500 rewards, 126635 frames, score 1, max score 9
# Completed 230 games, 502 rewards, 127169 frames, score 1, max score 9
# Completed 231 games, 503 rewards, 127423 frames, score 0, max score 9
# Completed 232 games, 506 rewards, 128247 frames, score 2, max score 9
# Completed 233 games, 507 rewards, 128455 frames, score 0, max score 9
# Completed 234 games, 508 rewards, 128636 frames, score 0, max score 9
# Completed 235 games, 510 rewards, 129003 frames, score 1, max score 9
# Completed 236 games, 511 rewards, 129211 frames, score 0, max score 9
# Completed 237 games, 514 rewards, 129822 frames, score 2, max score 9
# Completed 238 games, 515 rewards, 130076 frames, score 0, max score 9
# Completed 239 games, 516 rewards, 130284 frames, score 0, max score 9
# Completed 240 games, 520 rewards, 131937 frames, score 3, max score 9
# Completed 241 games, 522 rewards, 132527 frames, score 1, max score 9
# Completed 242 games, 523 rewards, 132708 frames, score 0, max score 9
# Completed 243 games, 525 rewards, 133060 frames, score 1, max score 9
# Completed 244 games, 529 rewards, 134421 frames, score 3, max score 9
# Completed 245 games, 531 rewards, 135011 frames, score 1, max score 9
# Completed 246 games, 534 rewards, 135599 frames, score 2, max score 9
# Completed 247 games, 535 rewards, 135853 frames, score 0, max score 9
# Completed 248 games, 537 rewards, 136194 frames, score 1, max score 9
# Completed 249 games, 540 rewards, 137961 frames, score 2, max score 9
# Completed 250 games, 543 rewards, 138591 frames, score 2, max score 9
# Completed 251 games, 547 rewards, 139244 frames, score 3, max score 9
# Completed 252 games, 555 rewards, 140595 frames, score 7, max score 9
# Completed 253 games, 556 rewards, 140776 frames, score 0, max score 9
# Completed 254 games, 560 rewards, 141610 frames, score 3, max score 9
# Completed 255 games, 563 rewards, 142587 frames, score 2, max score 9
# Completed 256 games, 564 rewards, 142795 frames, score 0, max score 9
# Completed 257 games, 565 rewards, 142976 frames, score 0, max score 9
# Completed 258 games, 570 rewards, 144006 frames, score 4, max score 9
# Completed 259 games, 572 rewards, 144412 frames, score 1, max score 9
# Completed 260 games, 575 rewards, 145091 frames, score 2, max score 9
# Completed 261 games, 578 rewards, 145490 frames, score 2, max score 9
# Completed 262 games, 579 rewards, 145744 frames, score 0, max score 9
# Completed 263 games, 582 rewards, 146334 frames, score 2, max score 9
# Completed 264 games, 584 rewards, 146846 frames, score 1, max score 9
# Completed 265 games, 586 rewards, 147765 frames, score 1, max score 9
# Completed 266 games, 590 rewards, 148445 frames, score 3, max score 9
# Completed 267 games, 593 rewards, 149096 frames, score 2, max score 9
# Completed 268 games, 594 rewards, 149304 frames, score 0, max score 9
# Completed 269 games, 597 rewards, 149994 frames, score 2, max score 9
# Completed 270 games, 598 rewards, 150175 frames, score 0, max score 9
# Completed 271 games, 599 rewards, 150356 frames, score 0, max score 9
# Completed 272 games, 600 rewards, 150564 frames, score 0, max score 9
# Completed 273 games, 602 rewards, 151166 frames, score 1, max score 9
# Completed 274 games, 604 rewards, 151571 frames, score 1, max score 9
# Completed 275 games, 605 rewards, 151752 frames, score 0, max score 9
# Completed 276 games, 607 rewards, 152328 frames, score 1, max score 9
# Completed 277 games, 610 rewards, 152969 frames, score 2, max score 9
# Completed 278 games, 613 rewards, 153523 frames, score 2, max score 9
# Completed 279 games, 618 rewards, 154734 frames, score 4, max score 9
# Completed 280 games, 620 rewards, 155075 frames, score 1, max score 9
# Completed 281 games, 622 rewards, 155665 frames, score 1, max score 9
# Completed 282 games, 623 rewards, 155873 frames, score 0, max score 9
# Completed 283 games, 627 rewards, 157409 frames, score 3, max score 9
# Completed 284 games, 629 rewards, 157869 frames, score 1, max score 9
# Completed 285 games, 633 rewards, 158564 frames, score 3, max score 9
# Completed 286 games, 634 rewards, 158818 frames, score 0, max score 9
# Completed 287 games, 641 rewards, 161569 frames, score 6, max score 9
# Completed 288 games, 647 rewards, 162671 frames, score 5, max score 9
# Completed 289 games, 648 rewards, 162925 frames, score 0, max score 9
# Completed 290 games, 649 rewards, 163106 frames, score 0, max score 9
# Completed 291 games, 650 rewards, 163287 frames, score 0, max score 9
# Completed 292 games, 652 rewards, 163799 frames, score 1, max score 9
# Completed 293 games, 656 rewards, 164484 frames, score 3, max score 9
# Completed 294 games, 657 rewards, 164665 frames, score 0, max score 9
# Completed 295 games, 660 rewards, 166689 frames, score 2, max score 9
# Completed 296 games, 661 rewards, 166943 frames, score 0, max score 9
# Completed 297 games, 663 rewards, 167677 frames, score 1, max score 9
# Completed 298 games, 664 rewards, 167858 frames, score 0, max score 9
# Completed 299 games, 667 rewards, 169606 frames, score 2, max score 9
# Completed 300 games, 668 rewards, 169860 frames, score 0, max score 9
# Completed 301 games, 671 rewards, 170602 frames, score 2, max score 9
# Completed 302 games, 678 rewards, 172058 frames, score 6, max score 9
# Completed 303 games, 680 rewards, 172426 frames, score 1, max score 9
# Completed 304 games, 684 rewards, 173199 frames, score 3, max score 9
# Completed 305 games, 685 rewards, 173380 frames, score 0, max score 9
# Completed 306 games, 686 rewards, 173588 frames, score 0, max score 9
# Completed 307 games, 687 rewards, 173796 frames, score 0, max score 9
# Completed 308 games, 692 rewards, 174801 frames, score 4, max score 9
# Completed 309 games, 696 rewards, 175441 frames, score 3, max score 9
# Completed 310 games, 703 rewards, 180439 frames, score 6, max score 9
# Completed 311 games, 704 rewards, 180693 frames, score 0, max score 9
# Completed 312 games, 705 rewards, 180947 frames, score 0, max score 9
# Completed 313 games, 715 rewards, 183023 frames, score 9, max score 9
# Completed 314 games, 720 rewards, 183905 frames, score 4, max score 9
# Completed 315 games, 721 rewards, 184113 frames, score 0, max score 9
# Completed 316 games, 722 rewards, 184294 frames, score 0, max score 9
# Completed 317 games, 724 rewards, 184661 frames, score 1, max score 9
# Completed 318 games, 725 rewards, 184915 frames, score 0, max score 9
# Completed 319 games, 728 rewards, 185545 frames, score 2, max score 9
# Completed 320 games, 732 rewards, 186383 frames, score 3, max score 9
# Completed 321 games, 737 rewards, 187191 frames, score 4, max score 9
# Completed 322 games, 738 rewards, 187399 frames, score 0, max score 9
# Completed 323 games, 740 rewards, 187950 frames, score 1, max score 9
# Completed 324 games, 741 rewards, 188204 frames, score 0, max score 9
# Completed 325 games, 745 rewards, 189235 frames, score 3, max score 9
# Completed 326 games, 747 rewards, 189723 frames, score 1, max score 9
# Completed 327 games, 750 rewards, 190445 frames, score 2, max score 9
# Completed 328 games, 754 rewards, 191636 frames, score 3, max score 9
# Completed 329 games, 756 rewards, 192019 frames, score 1, max score 9
# Completed 330 games, 758 rewards, 192425 frames, score 1, max score 9
# Completed 331 games, 763 rewards, 193306 frames, score 4, max score 9
# Completed 332 games, 764 rewards, 193514 frames, score 0, max score 9
# Completed 333 games, 767 rewards, 193931 frames, score 2, max score 9
# Completed 334 games, 768 rewards, 194139 frames, score 0, max score 9
# Completed 335 games, 770 rewards, 194602 frames, score 1, max score 9
# Completed 336 games, 772 rewards, 195204 frames, score 1, max score 9
# Completed 337 games, 779 rewards, 196791 frames, score 6, max score 9
# Completed 338 games, 785 rewards, 197929 frames, score 5, max score 9
# Completed 339 games, 787 rewards, 198366 frames, score 1, max score 9
# Completed 340 games, 791 rewards, 199397 frames, score 3, max score 9
# Completed 341 games, 798 rewards, 201699 frames, score 6, max score 9
# Completed 342 games, 803 rewards, 203392 frames, score 4, max score 9
# Completed 343 games, 810 rewards, 204762 frames, score 6, max score 9
# Completed 344 games, 815 rewards, 206426 frames, score 4, max score 9
# Completed 345 games, 818 rewards, 206965 frames, score 2, max score 9
# Completed 346 games, 823 rewards, 208022 frames, score 4, max score 9
# Completed 347 games, 829 rewards, 209292 frames, score 5, max score 9
# Completed 348 games, 833 rewards, 210045 frames, score 3, max score 9
# Completed 349 games, 837 rewards, 210712 frames, score 3, max score 9
# Completed 350 games, 848 rewards, 212836 frames, score 10, max score 10
# Completed 351 games, 850 rewards, 213498 frames, score 1, max score 10
# Completed 352 games, 853 rewards, 214145 frames, score 2, max score 10
# Completed 353 games, 858 rewards, 215200 frames, score 4, max score 10
# Completed 354 games, 859 rewards, 215408 frames, score 0, max score 10
# Completed 355 games, 860 rewards, 215589 frames, score 0, max score 10
# Completed 356 games, 861 rewards, 215770 frames, score 0, max score 10
# Completed 357 games, 862 rewards, 215978 frames, score 0, max score 10
# Completed 358 games, 864 rewards, 216441 frames, score 1, max score 10
# Completed 359 games, 866 rewards, 216901 frames, score 1, max score 10
# Completed 360 games, 873 rewards, 218016 frames, score 6, max score 10
# Completed 361 games, 875 rewards, 218678 frames, score 1, max score 10
# Completed 362 games, 876 rewards, 218932 frames, score 0, max score 10
# Completed 363 games, 889 rewards, 223116 frames, score 12, max score 12
# Completed 364 games, 894 rewards, 223991 frames, score 4, max score 12
# Completed 365 games, 897 rewards, 224541 frames, score 2, max score 12
# Completed 366 games, 898 rewards, 224749 frames, score 0, max score 12
# Completed 367 games, 905 rewards, 226182 frames, score 6, max score 12
# Completed 368 games, 912 rewards, 228239 frames, score 6, max score 12
# Completed 369 games, 914 rewards, 228739 frames, score 1, max score 12
# Completed 370 games, 915 rewards, 228993 frames, score 0, max score 12
# Completed 371 games, 923 rewards, 233024 frames, score 7, max score 12
# Completed 372 games, 924 rewards, 233278 frames, score 0, max score 12
# Completed 373 games, 926 rewards, 233619 frames, score 1, max score 12
# Completed 374 games, 928 rewards, 233987 frames, score 1, max score 12
# Completed 375 games, 932 rewards, 234667 frames, score 3, max score 12
# Completed 376 games, 936 rewards, 236123 frames, score 3, max score 12
# Completed 377 games, 938 rewards, 236674 frames, score 1, max score 12
# Completed 378 games, 939 rewards, 236855 frames, score 0, max score 12
# Completed 379 games, 948 rewards, 238689 frames, score 8, max score 12
# Completed 380 games, 949 rewards, 238943 frames, score 0, max score 12
# Completed 381 games, 951 rewards, 239284 frames, score 1, max score 12
# Completed 382 games, 953 rewards, 239636 frames, score 1, max score 12
# Completed 383 games, 960 rewards, 241503 frames, score 6, max score 12
# Completed 384 games, 964 rewards, 242491 frames, score 3, max score 12
# Completed 385 games, 966 rewards, 242905 frames, score 1, max score 12
# Completed 386 games, 978 rewards, 244858 frames, score 11, max score 12
# Completed 387 games, 979 rewards, 245112 frames, score 0, max score 12
# Completed 388 games, 980 rewards, 245293 frames, score 0, max score 12
# Completed 389 games, 987 rewards, 247505 frames, score 6, max score 12
# Completed 390 games, 990 rewards, 248527 frames, score 2, max score 12
# Completed 391 games, 993 rewards, 249197 frames, score 2, max score 12
# Completed 392 games, 1000 rewards, 250403 frames, score 6, max score 12
# Completed 393 games, 1002 rewards, 250843 frames, score 1, max score 12
# Completed 394 games, 1004 rewards, 251505 frames, score 1, max score 12
# Completed 395 games, 1005 rewards, 251759 frames, score 0, max score 12
# Completed 396 games, 1006 rewards, 251967 frames, score 0, max score 12
# Completed 397 games, 1007 rewards, 252221 frames, score 0, max score 12
# Completed 398 games, 1008 rewards, 252475 frames, score 0, max score 12
# Completed 399 games, 1013 rewards, 254129 frames, score 4, max score 12
# Completed 400 games, 1015 rewards, 254791 frames, score 1, max score 12
# Completed 401 games, 1019 rewards, 255626 frames, score 3, max score 12
# Completed 402 games, 1020 rewards, 255880 frames, score 0, max score 12
# Completed 403 games, 1022 rewards, 256278 frames, score 1, max score 12
# Completed 404 games, 1024 rewards, 256687 frames, score 1, max score 12
# Completed 405 games, 1030 rewards, 257932 frames, score 5, max score 12
# Completed 406 games, 1034 rewards, 258660 frames, score 3, max score 12
# Completed 407 games, 1042 rewards, 260236 frames, score 7, max score 12
# Completed 408 games, 1048 rewards, 261208 frames, score 5, max score 12
# Completed 409 games, 1051 rewards, 262771 frames, score 2, max score 12
# Completed 410 games, 1057 rewards, 264297 frames, score 5, max score 12
# Completed 411 games, 1058 rewards, 264505 frames, score 0, max score 12
# Completed 412 games, 1059 rewards, 264713 frames, score 0, max score 12
# Completed 413 games, 1062 rewards, 265290 frames, score 2, max score 12
# Completed 414 games, 1063 rewards, 265471 frames, score 0, max score 12
# Completed 415 games, 1064 rewards, 265725 frames, score 0, max score 12
# Completed 416 games, 1065 rewards, 265906 frames, score 0, max score 12
# Completed 417 games, 1067 rewards, 266496 frames, score 1, max score 12
# Completed 418 games, 1068 rewards, 266677 frames, score 0, max score 12
# Completed 419 games, 1069 rewards, 266931 frames, score 0, max score 12
# Completed 420 games, 1070 rewards, 267185 frames, score 0, max score 12
# Completed 421 games, 1072 rewards, 267552 frames, score 1, max score 12
# Completed 422 games, 1073 rewards, 267760 frames, score 0, max score 12
# Completed 423 games, 1074 rewards, 267941 frames, score 0, max score 12
# Completed 424 games, 1078 rewards, 269032 frames, score 3, max score 12
# Completed 425 games, 1079 rewards, 269240 frames, score 0, max score 12
# Completed 426 games, 1082 rewards, 270278 frames, score 2, max score 12
# Completed 427 games, 1086 rewards, 271303 frames, score 3, max score 12
# Completed 428 games, 1090 rewards, 272032 frames, score 3, max score 12
# Completed 429 games, 1091 rewards, 272286 frames, score 0, max score 12
# Completed 430 games, 1092 rewards, 272467 frames, score 0, max score 12
# Completed 431 games, 1095 rewards, 272836 frames, score 2, max score 12
# Completed 432 games, 1100 rewards, 273690 frames, score 4, max score 12
# Completed 433 games, 1104 rewards, 274435 frames, score 3, max score 12
# Completed 434 games, 1108 rewards, 275013 frames, score 3, max score 12
# Completed 435 games, 1113 rewards, 275976 frames, score 4, max score 12
# Completed 436 games, 1121 rewards, 277475 frames, score 7, max score 12
# Completed 437 games, 1122 rewards, 277729 frames, score 0, max score 12
# Completed 438 games, 1123 rewards, 277983 frames, score 0, max score 12
# Completed 439 games, 1124 rewards, 278237 frames, score 0, max score 12
# Completed 440 games, 1126 rewards, 279156 frames, score 1, max score 12
# Completed 441 games, 1128 rewards, 279497 frames, score 1, max score 12
# Completed 442 games, 1131 rewards, 280679 frames, score 2, max score 12
# Completed 443 games, 1132 rewards, 280860 frames, score 0, max score 12
# Completed 444 games, 1135 rewards, 281587 frames, score 2, max score 12
# Completed 445 games, 1140 rewards, 282584 frames, score 4, max score 12
# Completed 446 games, 1142 rewards, 282978 frames, score 1, max score 12
# Completed 447 games, 1145 rewards, 283548 frames, score 2, max score 12
# Completed 448 games, 1147 rewards, 283985 frames, score 1, max score 12
# Completed 449 games, 1151 rewards, 284689 frames, score 3, max score 12
# Completed 450 games, 1152 rewards, 284897 frames, score 0, max score 12
# Completed 451 games, 1155 rewards, 285642 frames, score 2, max score 12
# Completed 452 games, 1158 rewards, 286292 frames, score 2, max score 12
# Completed 453 games, 1164 rewards, 287301 frames, score 5, max score 12
# Completed 454 games, 1172 rewards, 291825 frames, score 7, max score 12
# Completed 455 games, 1179 rewards, 292984 frames, score 6, max score 12
# Completed 456 games, 1188 rewards, 296406 frames, score 8, max score 12
# Completed 457 games, 1192 rewards, 297114 frames, score 3, max score 12
# Completed 458 games, 1193 rewards, 297322 frames, score 0, max score 12
# Completed 459 games, 1195 rewards, 297720 frames, score 1, max score 12
# Completed 460 games, 1199 rewards, 298364 frames, score 3, max score 12
# Completed 461 games, 1200 rewards, 298572 frames, score 0, max score 12
# Completed 462 games, 1204 rewards, 299543 frames, score 3, max score 12
# Completed 463 games, 1214 rewards, 301235 frames, score 9, max score 12
# Completed 464 games, 1215 rewards, 301416 frames, score 0, max score 12
# Completed 465 games, 1216 rewards, 301670 frames, score 0, max score 12
# Completed 466 games, 1218 rewards, 302083 frames, score 1, max score 12
# Completed 467 games, 1221 rewards, 302609 frames, score 2, max score 12
# Completed 468 games, 1222 rewards, 302790 frames, score 0, max score 12
# Completed 469 games, 1223 rewards, 302971 frames, score 0, max score 12
# Completed 470 games, 1224 rewards, 303225 frames, score 0, max score 12
# Completed 471 games, 1225 rewards, 303406 frames, score 0, max score 12
# Completed 472 games, 1226 rewards, 303614 frames, score 0, max score 12
# Completed 473 games, 1228 rewards, 304048 frames, score 1, max score 12
# Completed 474 games, 1233 rewards, 305242 frames, score 4, max score 12
# Completed 475 games, 1234 rewards, 305423 frames, score 0, max score 12
# Completed 476 games, 1235 rewards, 305631 frames, score 0, max score 12
# Completed 477 games, 1236 rewards, 305812 frames, score 0, max score 12
# Completed 478 games, 1237 rewards, 305993 frames, score 0, max score 12
# Completed 479 games, 1240 rewards, 306753 frames, score 2, max score 12
# Completed 480 games, 1241 rewards, 307007 frames, score 0, max score 12
# Completed 481 games, 1247 rewards, 307983 frames, score 5, max score 12
# Completed 482 games, 1248 rewards, 308191 frames, score 0, max score 12
# Completed 483 games, 1249 rewards, 308445 frames, score 0, max score 12
# Completed 484 games, 1254 rewards, 309987 frames, score 4, max score 12
# Completed 485 games, 1255 rewards, 310168 frames, score 0, max score 12
# Completed 486 games, 1256 rewards, 310422 frames, score 0, max score 12
# Completed 487 games, 1261 rewards, 311220 frames, score 4, max score 12
# Completed 488 games, 1263 rewards, 311680 frames, score 1, max score 12
# Completed 489 games, 1265 rewards, 312143 frames, score 1, max score 12
# Completed 490 games, 1266 rewards, 312397 frames, score 0, max score 12
# Completed 491 games, 1274 rewards, 313799 frames, score 7, max score 12
# Completed 492 games, 1275 rewards, 314007 frames, score 0, max score 12
# Completed 493 games, 1279 rewards, 314705 frames, score 3, max score 12
# Completed 494 games, 1280 rewards, 314959 frames, score 0, max score 12
# Completed 495 games, 1282 rewards, 315327 frames, score 1, max score 12
# Completed 496 games, 1284 rewards, 315832 frames, score 1, max score 12
# Completed 497 games, 1285 rewards, 316040 frames, score 0, max score 12
# Completed 498 games, 1288 rewards, 318064 frames, score 2, max score 12
# Completed 499 games, 1293 rewards, 319031 frames, score 4, max score 12
# Completed 500 games, 1295 rewards, 319539 frames, score 1, max score 12
# Completed 501 games, 1296 rewards, 319747 frames, score 0, max score 12
# Completed 502 games, 1298 rewards, 320152 frames, score 1, max score 12
# Completed 503 games, 1312 rewards, 322380 frames, score 13, max score 13
# Completed 504 games, 1313 rewards, 322588 frames, score 0, max score 13
# Completed 505 games, 1318 rewards, 323370 frames, score 4, max score 13
# Completed 506 games, 1320 rewards, 323807 frames, score 1, max score 13
# Completed 507 games, 1324 rewards, 325797 frames, score 3, max score 13
# Completed 508 games, 1327 rewards, 327372 frames, score 2, max score 13
# Completed 509 games, 1328 rewards, 327553 frames, score 0, max score 13
# Completed 510 games, 1334 rewards, 328462 frames, score 5, max score 13
# Completed 511 games, 1337 rewards, 329077 frames, score 2, max score 13
# Completed 512 games, 1341 rewards, 330438 frames, score 3, max score 13
# Completed 513 games, 1347 rewards, 331521 frames, score 5, max score 13
# Completed 514 games, 1349 rewards, 331889 frames, score 1, max score 13
# Completed 515 games, 1351 rewards, 332368 frames, score 1, max score 13
# Completed 516 games, 1354 rewards, 333021 frames, score 2, max score 13
# Completed 517 games, 1357 rewards, 333647 frames, score 2, max score 13
# Completed 518 games, 1362 rewards, 335731 frames, score 4, max score 13
# Completed 519 games, 1369 rewards, 338805 frames, score 6, max score 13
# Completed 520 games, 1372 rewards, 339690 frames, score 2, max score 13
# Completed 521 games, 1374 rewards, 340096 frames, score 1, max score 13
# Completed 522 games, 1375 rewards, 340277 frames, score 0, max score 13
# Completed 523 games, 1377 rewards, 340664 frames, score 1, max score 13
# Completed 524 games, 1384 rewards, 343193 frames, score 6, max score 13
# Completed 525 games, 1385 rewards, 343447 frames, score 0, max score 13
# Completed 526 games, 1390 rewards, 344516 frames, score 4, max score 13
# Completed 527 games, 1391 rewards, 344724 frames, score 0, max score 13
# Completed 528 games, 1393 rewards, 345076 frames, score 1, max score 13
# Completed 529 games, 1395 rewards, 345627 frames, score 1, max score 13
# Completed 530 games, 1398 rewards, 346206 frames, score 2, max score 13
# Completed 531 games, 1403 rewards, 348156 frames, score 4, max score 13
# Completed 532 games, 1406 rewards, 348782 frames, score 2, max score 13
# Completed 533 games, 1409 rewards, 349393 frames, score 2, max score 13
# Completed 534 games, 1411 rewards, 349983 frames, score 1, max score 13
# Completed 535 games, 1415 rewards, 351033 frames, score 3, max score 13
# Completed 536 games, 1417 rewards, 351444 frames, score 1, max score 13
# Completed 537 games, 1420 rewards, 351977 frames, score 2, max score 13
# Completed 538 games, 1421 rewards, 352185 frames, score 0, max score 13
# Completed 539 games, 1424 rewards, 352740 frames, score 2, max score 13
# Completed 540 games, 1432 rewards, 354971 frames, score 7, max score 13
# Completed 541 games, 1434 rewards, 355339 frames, score 1, max score 13
# Completed 542 games, 1439 rewards, 356333 frames, score 4, max score 13
# Completed 543 games, 1443 rewards, 357092 frames, score 3, max score 13
# Completed 544 games, 1444 rewards, 357300 frames, score 0, max score 13
# Completed 545 games, 1450 rewards, 358379 frames, score 5, max score 13
# Completed 546 games, 1454 rewards, 359179 frames, score 3, max score 13
# Completed 547 games, 1459 rewards, 360267 frames, score 4, max score 13
# Completed 548 games, 1460 rewards, 360521 frames, score 0, max score 13
# Completed 549 games, 1462 rewards, 361111 frames, score 1, max score 13
# Completed 550 games, 1463 rewards, 361365 frames, score 0, max score 13
# Completed 551 games, 1464 rewards, 361546 frames, score 0, max score 13
# Completed 552 games, 1470 rewards, 362526 frames, score 5, max score 13
# Completed 553 games, 1471 rewards, 362780 frames, score 0, max score 13
# Completed 554 games, 1474 rewards, 363461 frames, score 2, max score 13
# Completed 555 games, 1479 rewards, 364653 frames, score 4, max score 13
# Completed 556 games, 1480 rewards, 364907 frames, score 0, max score 13
# Completed 557 games, 1484 rewards, 365717 frames, score 3, max score 13
# Completed 558 games, 1485 rewards, 365971 frames, score 0, max score 13
# Completed 559 games, 1486 rewards, 366152 frames, score 0, max score 13
# Completed 560 games, 1489 rewards, 366795 frames, score 2, max score 13
# Completed 561 games, 1491 rewards, 367371 frames, score 1, max score 13
# Completed 562 games, 1494 rewards, 367877 frames, score 2, max score 13
# Completed 563 games, 1497 rewards, 368751 frames, score 2, max score 13
# Completed 564 games, 1498 rewards, 368959 frames, score 0, max score 13
# Completed 565 games, 1503 rewards, 370190 frames, score 4, max score 13
# Completed 566 games, 1511 rewards, 372808 frames, score 7, max score 13
# Completed 567 games, 1512 rewards, 373062 frames, score 0, max score 13
# Completed 568 games, 1513 rewards, 373243 frames, score 0, max score 13
# Completed 569 games, 1519 rewards, 374610 frames, score 5, max score 13
# Completed 570 games, 1521 rewards, 375107 frames, score 1, max score 13
# Completed 571 games, 1523 rewards, 375535 frames, score 1, max score 13
# Completed 572 games, 1527 rewards, 378096 frames, score 3, max score 13
# Completed 573 games, 1533 rewards, 379470 frames, score 5, max score 13
# Completed 574 games, 1543 rewards, 384984 frames, score 9, max score 13
# Completed 575 games, 1546 rewards, 385531 frames, score 2, max score 13
# Completed 576 games, 1551 rewards, 387029 frames, score 4, max score 13
# Completed 577 games, 1552 rewards, 387237 frames, score 0, max score 13
# Completed 578 games, 1553 rewards, 387418 frames, score 0, max score 13
# Completed 579 games, 1558 rewards, 388566 frames, score 4, max score 13
# Completed 580 games, 1560 rewards, 388949 frames, score 1, max score 13
# Completed 581 games, 1562 rewards, 389868 frames, score 1, max score 13
# Completed 582 games, 1572 rewards, 394412 frames, score 9, max score 13
# Completed 583 games, 1573 rewards, 394620 frames, score 0, max score 13
# Completed 584 games, 1574 rewards, 394801 frames, score 0, max score 13
# Completed 585 games, 1581 rewards, 397054 frames, score 6, max score 13
# Completed 586 games, 1582 rewards, 397235 frames, score 0, max score 13
# Completed 587 games, 1590 rewards, 398677 frames, score 7, max score 13
# Completed 588 games, 1607 rewards, 409755 frames, score 16, max score 16
# Completed 589 games, 1609 rewards, 410267 frames, score 1, max score 16
# Completed 590 games, 1611 rewards, 410929 frames, score 1, max score 16
# Completed 591 games, 1612 rewards, 411183 frames, score 0, max score 16
# Completed 592 games, 1615 rewards, 411807 frames, score 2, max score 16
# Completed 593 games, 1620 rewards, 412849 frames, score 4, max score 16
# Completed 594 games, 1622 rewards, 413320 frames, score 1, max score 16
# Completed 595 games, 1625 rewards, 414098 frames, score 2, max score 16
# Completed 596 games, 1634 rewards, 416105 frames, score 8, max score 16
# Completed 597 games, 1636 rewards, 416681 frames, score 1, max score 16
# Completed 598 games, 1637 rewards, 416935 frames, score 0, max score 16
# Completed 599 games, 1639 rewards, 417345 frames, score 1, max score 16
# Completed 600 games, 1640 rewards, 417599 frames, score 0, max score 16
# Completed 601 games, 1643 rewards, 418136 frames, score 2, max score 16
# Completed 602 games, 1646 rewards, 418783 frames, score 2, max score 16
# Completed 603 games, 1649 rewards, 419490 frames, score 2, max score 16
# Completed 604 games, 1651 rewards, 419895 frames, score 1, max score 16
# Completed 605 games, 1655 rewards, 420795 frames, score 3, max score 16
# Completed 606 games, 1661 rewards, 421659 frames, score 5, max score 16
# Completed 607 games, 1662 rewards, 421840 frames, score 0, max score 16
# Completed 608 games, 1667 rewards, 422821 frames, score 4, max score 16
# Completed 609 games, 1669 rewards, 423226 frames, score 1, max score 16
# Completed 610 games, 1670 rewards, 423407 frames, score 0, max score 16
# Completed 611 games, 1675 rewards, 424681 frames, score 4, max score 16
# Completed 612 games, 1686 rewards, 428586 frames, score 10, max score 16
# Completed 613 games, 1690 rewards, 429513 frames, score 3, max score 16
# Completed 614 games, 1691 rewards, 429694 frames, score 0, max score 16
# Completed 615 games, 1692 rewards, 429902 frames, score 0, max score 16
# Completed 616 games, 1695 rewards, 430401 frames, score 2, max score 16
# Completed 617 games, 1698 rewards, 431150 frames, score 2, max score 16
# Completed 618 games, 1700 rewards, 431521 frames, score 1, max score 16
# Completed 619 games, 1701 rewards, 431702 frames, score 0, max score 16
# Completed 620 games, 1702 rewards, 431956 frames, score 0, max score 16
# Completed 621 games, 1703 rewards, 432164 frames, score 0, max score 16
# Completed 622 games, 1706 rewards, 432807 frames, score 2, max score 16
# Completed 623 games, 1712 rewards, 434139 frames, score 5, max score 16
# Completed 624 games, 1713 rewards, 434320 frames, score 0, max score 16
# Completed 625 games, 1716 rewards, 434940 frames, score 2, max score 16
# Completed 626 games, 1717 rewards, 435194 frames, score 0, max score 16
# Completed 627 games, 1720 rewards, 435735 frames, score 2, max score 16
# Completed 628 games, 1724 rewards, 436462 frames, score 3, max score 16
# Completed 629 games, 1725 rewards, 436716 frames, score 0, max score 16
# Completed 630 games, 1729 rewards, 437954 frames, score 3, max score 16
# Completed 631 games, 1732 rewards, 438524 frames, score 2, max score 16
# Completed 632 games, 1736 rewards, 440055 frames, score 3, max score 16
# Completed 633 games, 1737 rewards, 440309 frames, score 0, max score 16
# Completed 634 games, 1739 rewards, 440971 frames, score 1, max score 16
# Completed 635 games, 1740 rewards, 441179 frames, score 0, max score 16
# Completed 636 games, 1744 rewards, 442394 frames, score 3, max score 16
# Completed 637 games, 1746 rewards, 442800 frames, score 1, max score 16
# Completed 638 games, 1749 rewards, 443548 frames, score 2, max score 16
# Completed 639 games, 1752 rewards, 444297 frames, score 2, max score 16
# Completed 640 games, 1759 rewards, 445578 frames, score 6, max score 16
# Completed 641 games, 1760 rewards, 445786 frames, score 0, max score 16
# Completed 642 games, 1764 rewards, 447027 frames, score 3, max score 16
# Completed 643 games, 1768 rewards, 447952 frames, score 3, max score 16
# Completed 644 games, 1771 rewards, 448652 frames, score 2, max score 16
# Completed 645 games, 1772 rewards, 448860 frames, score 0, max score 16
# Completed 646 games, 1780 rewards, 451470 frames, score 7, max score 16
# Completed 647 games, 1781 rewards, 451678 frames, score 0, max score 16
# Completed 648 games, 1784 rewards, 452397 frames, score 2, max score 16
# Completed 649 games, 1786 rewards, 452860 frames, score 1, max score 16
# Completed 650 games, 1793 rewards, 454125 frames, score 6, max score 16
# Completed 651 games, 1801 rewards, 456838 frames, score 7, max score 16
# Completed 652 games, 1802 rewards, 457019 frames, score 0, max score 16
# Completed 653 games, 1804 rewards, 457482 frames, score 1, max score 16
# Completed 654 games, 1806 rewards, 457936 frames, score 1, max score 16
# Completed 655 games, 1807 rewards, 458117 frames, score 0, max score 16
# Completed 656 games, 1808 rewards, 458371 frames, score 0, max score 16
# Completed 657 games, 1811 rewards, 459267 frames, score 2, max score 16
# Completed 658 games, 1816 rewards, 460230 frames, score 4, max score 16
# Completed 659 games, 1817 rewards, 460438 frames, score 0, max score 16
# Completed 660 games, 1818 rewards, 460619 frames, score 0, max score 16
# Completed 661 games, 1819 rewards, 460873 frames, score 0, max score 16
# Completed 662 games, 1820 rewards, 461081 frames, score 0, max score 16
# Completed 663 games, 1821 rewards, 461335 frames, score 0, max score 16
# Completed 664 games, 1824 rewards, 461892 frames, score 2, max score 16
# Completed 665 games, 1825 rewards, 462073 frames, score 0, max score 16
# Completed 666 games, 1837 rewards, 467562 frames, score 11, max score 16
# Completed 667 games, 1845 rewards, 469089 frames, score 7, max score 16
# Completed 668 games, 1849 rewards, 470677 frames, score 3, max score 16
# Completed 669 games, 1851 rewards, 471174 frames, score 1, max score 16
# Completed 670 games, 1853 rewards, 471580 frames, score 1, max score 16
# Completed 671 games, 1854 rewards, 471788 frames, score 0, max score 16
# Completed 672 games, 1860 rewards, 473374 frames, score 5, max score 16
# Completed 673 games, 1872 rewards, 475347 frames, score 11, max score 16
# Completed 674 games, 1876 rewards, 476316 frames, score 3, max score 16
# Completed 675 games, 1879 rewards, 476832 frames, score 2, max score 16
# Completed 676 games, 1884 rewards, 477982 frames, score 4, max score 16
# Completed 677 games, 1887 rewards, 478634 frames, score 2, max score 16
# Completed 678 games, 1888 rewards, 478842 frames, score 0, max score 16
# Completed 679 games, 1889 rewards, 479023 frames, score 0, max score 16
# Completed 680 games, 1890 rewards, 479204 frames, score 0, max score 16
# ...
# Completed 4797 games, 51982 rewards, 12183560 frames, score 106, max score 352
# Completed 4798 games, 52032 rewards, 12194562 frames, score 49, max score 352
# Completed 4799 games, 52050 rewards, 12197246 frames, score 17, max score 352
# Completed 4800 games, 52062 rewards, 12199176 frames, score 11, max score 352
# Completed 4801 games, 52082 rewards, 12208055 frames, score 19, max score 352
# Completed 4802 games, 52092 rewards, 12209839 frames, score 9, max score 352
# Completed 4803 games, 52159 rewards, 12223913 frames, score 66, max score 352
# Completed 4804 games, 52204 rewards, 12242887 frames, score 44, max score 352
# Completed 4805 games, 52216 rewards, 12246232 frames, score 11, max score 352
# Completed 4806 games, 52341 rewards, 12265183 frames, score 124, max score 352
# Completed 4807 games, 52582 rewards, 12304696 frames, score 240, max score 352
# Completed 4808 games, 52639 rewards, 12314300 frames, score 56, max score 352
# Completed 4809 games, 52686 rewards, 12321666 frames, score 46, max score 352
# Completed 4810 games, 52692 rewards, 12322848 frames, score 5, max score 352
# Completed 4811 games, 52703 rewards, 12324710 frames, score 10, max score 352
# Completed 4812 games, 52845 rewards, 12352334 frames, score 141, max score 352
# Completed 4813 games, 52847 rewards, 12352739 frames, score 1, max score 352
# Completed 4814 games, 53083 rewards, 12388329 frames, score 235, max score 352
# Completed 4815 games, 53108 rewards, 12392554 frames, score 24, max score 352
# Completed 4816 games, 53110 rewards, 12393051 frames, score 1, max score 352
# Completed 4817 games, 53267 rewards, 12422519 frames, score 156, max score 352
# Completed 4818 games, 53324 rewards, 12433978 frames, score 56, max score 352
# Completed 4819 games, 53556 rewards, 12469211 frames, score 231, max score 352
# Completed 4820 games, 53689 rewards, 12491070 frames, score 132, max score 352
# Completed 4821 games, 53883 rewards, 12529159 frames, score 193, max score 352
# Completed 4822 games, 53912 rewards, 12535023 frames, score 28, max score 352
# Completed 4823 games, 53981 rewards, 12548513 frames, score 68, max score 352
# Completed 4824 games, 54020 rewards, 12554307 frames, score 38, max score 352
# Completed 4825 games, 54146 rewards, 12588492 frames, score 125, max score 352
# Completed 4826 games, 54199 rewards, 12598257 frames, score 52, max score 352
# Completed 4827 games, 54686 rewards, 12679433 frames, score 486, max score 486
# Completed 4828 games, 54702 rewards, 12682608 frames, score 15, max score 486
# Completed 4829 games, 54898 rewards, 12719794 frames, score 195, max score 486
# Completed 4830 games, 55152 rewards, 12758167 frames, score 253, max score 486
# Completed 4831 games, 55176 rewards, 12764433 frames, score 23, max score 486
# Completed 4832 games, 55309 rewards, 12788229 frames, score 132, max score 486
# Completed 4833 games, 55339 rewards, 12794157 frames, score 29, max score 486
# Completed 4834 games, 55398 rewards, 12806822 frames, score 58, max score 486
# Completed 4835 games, 55808 rewards, 12891860 frames, score 409, max score 486
# Completed 4836 games, 55897 rewards, 12907963 frames, score 88, max score 486
# Completed 4837 games, 55990 rewards, 12927997 frames, score 92, max score 486
# Completed 4838 games, 56100 rewards, 12946775 frames, score 109, max score 486
# Completed 4839 games, 56419 rewards, 12999785 frames, score 318, max score 486
# Completed 4840 games, 56439 rewards, 13002783 frames, score 19, max score 486
# Completed 4841 games, 56770 rewards, 13065867 frames, score 330, max score 486
# Completed 4842 games, 56836 rewards, 13076893 frames, score 65, max score 486
# Completed 4843 games, 56885 rewards, 13086101 frames, score 48, max score 486
# Completed 4844 games, 57148 rewards, 13133697 frames, score 262, max score 486
# Completed 4845 games, 57175 rewards, 13138835 frames, score 26, max score 486
# Completed 4846 games, 57304 rewards, 13162607 frames, score 128, max score 486
# Completed 4847 games, 57405 rewards, 13178574 frames, score 100, max score 486
# Completed 4848 games, 57601 rewards, 13211281 frames, score 195, max score 486
# Completed 4849 games, 57634 rewards, 13216204 frames, score 32, max score 486
# Completed 4850 games, 57770 rewards, 13239957 frames, score 135, max score 486
# Completed 4851 games, 57895 rewards, 13261107 frames, score 124, max score 486
# Completed 4852 games, 58147 rewards, 13320909 frames, score 251, max score 486
# Completed 4853 games, 58238 rewards, 13337161 frames, score 90, max score 486
# Completed 4854 games, 58266 rewards, 13341986 frames, score 27, max score 486
# Completed 4855 games, 58420 rewards, 13372989 frames, score 153, max score 486
# Completed 4856 games, 58683 rewards, 13433562 frames, score 262, max score 486
# Completed 4857 games, 58826 rewards, 13460591 frames, score 142, max score 486
# Completed 4858 games, 58936 rewards, 13489627 frames, score 109, max score 486
# Completed 4859 games, 58939 rewards, 13490107 frames, score 2, max score 486
# Completed 4860 games, 58990 rewards, 13511763 frames, score 50, max score 486
# Completed 4861 games, 59279 rewards, 13562362 frames, score 288, max score 486
# Completed 4862 games, 59290 rewards, 13564801 frames, score 10, max score 486
# Completed 4863 games, 59293 rewards, 13565336 frames, score 2, max score 486
# Completed 4864 games, 59363 rewards, 13575976 frames, score 69, max score 486
# Completed 4865 games, 59369 rewards, 13577032 frames, score 5, max score 486
# Completed 4866 games, 59464 rewards, 13592013 frames, score 94, max score 486
# Completed 4867 games, 59475 rewards, 13594345 frames, score 10, max score 486
# Completed 4868 games, 59596 rewards, 13616893 frames, score 120, max score 486
# Completed 4869 games, 59702 rewards, 13634494 frames, score 105, max score 486
# Completed 4870 games, 59797 rewards, 13655817 frames, score 94, max score 486
# Completed 4871 games, 59901 rewards, 13675210 frames, score 103, max score 486
# Completed 4872 games, 60001 rewards, 13690857 frames, score 99, max score 486
# Completed 4873 games, 60073 rewards, 13702240 frames, score 71, max score 486
# Completed 4874 games, 60102 rewards, 13706560 frames, score 28, max score 486
# Completed 4875 games, 60135 rewards, 13711639 frames, score 32, max score 486
# Completed 4876 games, 60159 rewards, 13716070 frames, score 23, max score 486
# Completed 4877 games, 60401 rewards, 13757453 frames, score 241, max score 486
# Completed 4878 games, 60526 rewards, 13795756 frames, score 124, max score 486
# Completed 4879 games, 60711 rewards, 13829047 frames, score 184, max score 486
# Completed 4880 games, 60811 rewards, 13847143 frames, score 99, max score 486
# Completed 4881 games, 60826 rewards, 13850371 frames, score 14, max score 486
# Completed 4882 games, 60909 rewards, 13867281 frames, score 82, max score 486
# Completed 4883 games, 61115 rewards, 13901244 frames, score 205, max score 486
# Completed 4884 games, 61134 rewards, 13907180 frames, score 18, max score 486
# Completed 4885 games, 61251 rewards, 13926924 frames, score 116, max score 486
# Completed 4886 games, 61260 rewards, 13929946 frames, score 8, max score 486
# Completed 4887 games, 61282 rewards, 13933750 frames, score 21, max score 486
# Completed 4888 games, 61299 rewards, 13936920 frames, score 16, max score 486
# Completed 4889 games, 61374 rewards, 13949046 frames, score 74, max score 486
# Completed 4890 games, 61484 rewards, 13966676 frames, score 109, max score 486
# Completed 4891 games, 61572 rewards, 13981185 frames, score 87, max score 486
# Completed 4892 games, 61575 rewards, 13981994 frames, score 2, max score 486
# Completed 4893 games, 61636 rewards, 13993354 frames, score 60, max score 486
# Completed 4894 games, 61713 rewards, 14015654 frames, score 76, max score 486
# Completed 4895 games, 61764 rewards, 14028825 frames, score 50, max score 486
# Completed 4896 games, 61812 rewards, 14037093 frames, score 47, max score 486
# Completed 4897 games, 61861 rewards, 14044350 frames, score 48, max score 486
# Completed 4898 games, 61897 rewards, 14050378 frames, score 35, max score 486
# Completed 4899 games, 62039 rewards, 14080516 frames, score 141, max score 486
# Completed 4900 games, 62208 rewards, 14121331 frames, score 168, max score 486
# Completed 4901 games, 62536 rewards, 14177864 frames, score 327, max score 486
# Completed 4902 games, 62556 rewards, 14181049 frames, score 19, max score 486
# Completed 4903 games, 62580 rewards, 14184647 frames, score 23, max score 486
# Completed 4904 games, 62663 rewards, 14204988 frames, score 82, max score 486
# Completed 4905 games, 62678 rewards, 14213353 frames, score 14, max score 486
# Completed 4906 games, 62719 rewards, 14220602 frames, score 40, max score 486
# Completed 4907 games, 62778 rewards, 14229475 frames, score 58, max score 486
# Completed 4908 games, 62807 rewards, 14233924 frames, score 28, max score 486
# Completed 4909 games, 62873 rewards, 14248473 frames, score 65, max score 486
# Completed 4910 games, 62893 rewards, 14260269 frames, score 19, max score 486
# Completed 4911 games, 63057 rewards, 14290808 frames, score 163, max score 486
# Completed 4912 games, 63066 rewards, 14294366 frames, score 8, max score 486
# Completed 4913 games, 63101 rewards, 14300544 frames, score 34, max score 486
# Completed 4914 games, 63112 rewards, 14302363 frames, score 10, max score 486
# Completed 4915 games, 63126 rewards, 14304878 frames, score 13, max score 486
# Completed 4916 games, 63164 rewards, 14311683 frames, score 37, max score 486
# Completed 4917 games, 63286 rewards, 14330419 frames, score 121, max score 486
# Completed 4918 games, 63324 rewards, 14336084 frames, score 37, max score 486
# Completed 4919 games, 63367 rewards, 14342705 frames, score 42, max score 486
# Completed 4920 games, 63389 rewards, 14348161 frames, score 21, max score 486
# Completed 4921 games, 63403 rewards, 14350425 frames, score 13, max score 486
# Completed 4922 games, 63519 rewards, 14368538 frames, score 115, max score 486
# Completed 4923 games, 63521 rewards, 14368921 frames, score 1, max score 486
# Completed 4924 games, 63717 rewards, 14406849 frames, score 195, max score 486
# Completed 4925 games, 63722 rewards, 14407819 frames, score 4, max score 486
# Completed 4926 games, 63754 rewards, 14413179 frames, score 31, max score 486
# Completed 4927 games, 63928 rewards, 14439350 frames, score 173, max score 486
# Completed 4928 games, 63943 rewards, 14441754 frames, score 14, max score 486
# Completed 4929 games, 63972 rewards, 14446225 frames, score 28, max score 486
# Completed 4930 games, 63974 rewards, 14447144 frames, score 1, max score 486
# Completed 4931 games, 64035 rewards, 14457036 frames, score 60, max score 486
# Completed 4932 games, 64063 rewards, 14461527 frames, score 27, max score 486
# Completed 4933 games, 64074 rewards, 14463457 frames, score 10, max score 486
# Completed 4934 games, 64438 rewards, 14518221 frames, score 363, max score 486
# Completed 4935 games, 64457 rewards, 14521775 frames, score 18, max score 486
# Completed 4936 games, 64578 rewards, 14542956 frames, score 120, max score 486
# Completed 4937 games, 64595 rewards, 14545687 frames, score 16, max score 486
# Completed 4938 games, 64603 rewards, 14548901 frames, score 7, max score 486
# Completed 4939 games, 64612 rewards, 14554381 frames, score 8, max score 486
# Completed 4940 games, 64633 rewards, 14557839 frames, score 20, max score 486
# Completed 4941 games, 64660 rewards, 14565513 frames, score 26, max score 486
# Completed 4942 games, 64673 rewards, 14569834 frames, score 12, max score 486
# Completed 4943 games, 64677 rewards, 14570607 frames, score 3, max score 486
# Completed 4944 games, 64698 rewards, 14574563 frames, score 20, max score 486
# Completed 4945 games, 64708 rewards, 14576211 frames, score 9, max score 486
# Completed 4946 games, 64760 rewards, 14588628 frames, score 51, max score 486
# Completed 4947 games, 64798 rewards, 14597927 frames, score 37, max score 486
# Completed 4948 games, 64856 rewards, 14607774 frames, score 57, max score 486
# Completed 4949 games, 64863 rewards, 14608933 frames, score 6, max score 486
# Completed 4950 games, 64873 rewards, 14613479 frames, score 9, max score 486
# Completed 4951 games, 65007 rewards, 14636323 frames, score 133, max score 486
# Completed 4952 games, 65059 rewards, 14644825 frames, score 51, max score 486
# Completed 4953 games, 65104 rewards, 14655896 frames, score 44, max score 486
# Completed 4954 games, 65145 rewards, 14668648 frames, score 40, max score 486
# Completed 4955 games, 65268 rewards, 14692119 frames, score 122, max score 486
# Completed 4956 games, 65312 rewards, 14699765 frames, score 43, max score 486
# Completed 4957 games, 65374 rewards, 14709847 frames, score 61, max score 486
# Completed 4958 games, 65393 rewards, 14712707 frames, score 18, max score 486
# Completed 4959 games, 65405 rewards, 14714652 frames, score 11, max score 486
# Completed 4960 games, 65425 rewards, 14718087 frames, score 19, max score 486
# Completed 4961 games, 65439 rewards, 14720646 frames, score 13, max score 486
# Completed 4962 games, 65450 rewards, 14724299 frames, score 10, max score 486
# Completed 4963 games, 65465 rewards, 14726843 frames, score 14, max score 486
# Completed 4964 games, 65536 rewards, 14744801 frames, score 70, max score 486
# Completed 4965 games, 65548 rewards, 14746905 frames, score 11, max score 486
# Completed 4966 games, 65558 rewards, 14748860 frames, score 9, max score 486
# Completed 4967 games, 65569 rewards, 14750693 frames, score 10, max score 486
# Completed 4968 games, 65593 rewards, 14754755 frames, score 23, max score 486
# Completed 4969 games, 65632 rewards, 14761139 frames, score 38, max score 486
# Completed 4970 games, 65650 rewards, 14763928 frames, score 17, max score 486
# Completed 4971 games, 65677 rewards, 14773612 frames, score 26, max score 486
# Completed 4972 games, 65682 rewards, 14774517 frames, score 4, max score 486
# Completed 4973 games, 65768 rewards, 14789466 frames, score 85, max score 486
# Completed 4974 games, 65818 rewards, 14797813 frames, score 49, max score 486
# Completed 4975 games, 65876 rewards, 14808292 frames, score 57, max score 486
# Completed 4976 games, 65894 rewards, 14812920 frames, score 17, max score 486
# Completed 4977 games, 65922 rewards, 14823545 frames, score 27, max score 486
# Completed 4978 games, 65929 rewards, 14824922 frames, score 6, max score 486
# Completed 4979 games, 65948 rewards, 14828190 frames, score 18, max score 486
# Completed 4980 games, 65956 rewards, 14829852 frames, score 7, max score 486
# Completed 4981 games, 65976 rewards, 14832857 frames, score 19, max score 486
# Completed 4982 games, 65983 rewards, 14833909 frames, score 6, max score 486
# Completed 4983 games, 65991 rewards, 14835196 frames, score 7, max score 486
# Completed 4984 games, 66037 rewards, 14844932 frames, score 45, max score 486
# Completed 4985 games, 66044 rewards, 14846225 frames, score 6, max score 486
# Completed 4986 games, 66053 rewards, 14848046 frames, score 8, max score 486
# Completed 4987 games, 66057 rewards, 14848780 frames, score 3, max score 486
# Completed 4988 games, 66064 rewards, 14849943 frames, score 6, max score 486
# Completed 4989 games, 66107 rewards, 14857947 frames, score 42, max score 486
# Completed 4990 games, 66119 rewards, 14859794 frames, score 11, max score 486
# Completed 4991 games, 66127 rewards, 14861413 frames, score 7, max score 486
# Completed 4992 games, 66164 rewards, 14871017 frames, score 36, max score 486
# Completed 4993 games, 66196 rewards, 14885635 frames, score 31, max score 486
# Completed 4994 games, 66213 rewards, 14889053 frames, score 16, max score 486
# Completed 4995 games, 66262 rewards, 14901745 frames, score 48, max score 486
# Completed 4996 games, 66272 rewards, 14906540 frames, score 9, max score 486
# Completed 4997 games, 66294 rewards, 14909862 frames, score 21, max score 486
# Completed 4998 games, 66320 rewards, 14914773 frames, score 25, max score 486
# Completed 4999 games, 66325 rewards, 14916519 frames, score 4, max score 486
# The number of games played was 5000
# The number of video frames was 5000
# The size of each returned Q-matrix was (0,)

# %% [markdown]
# Now let's plot the score, to see if it improved over time.  We will also plot the local average, averaged over 10 consecutive games, to see if that has improved.  Notice that we can use `np.convolve` to compute the local average.
#
# These numbers are really noisy, with a really large maximum.  We will plot `np.log10(1+x)`, rather than x, so that we can better see the average numbers, and ignore the very large noisy spikes.

# %%
# %matplotlib inline

import matplotlib.pyplot as plt

fig = plt.figure(figsize=(14,9),layout='tight')
ax = [ fig.add_subplot(3,1,x) for x in range(1,4) ]
ax[0].plot(np.arange(0,len(scores)),np.log10(1+np.array(scores)))
ax[0].plot([0,5000],np.log10([7,7]),'k--')
ax[0].set_title('Game scores')
ax[1].plot(np.arange(4991),np.log10(1+np.convolve(np.ones(10)/10,scores,mode='valid')))
ax[1].plot([0,4991],np.log10([7,7]),'k--')
ax[1].set_title('Game scores, average 10 consecutive games')
ax[2].plot(np.arange(0,len(q_achieved)),q_achieved)
ax[2].set_title('Q values of state achieved at each time')
ax[2].set_ylabel('Game number')
# Out:
# Text(0, 0.5, 'Game number')

# %% [markdown]
# Hooray, it has learned!  If you are getting a ten-game average score of better than 6, then you are ready to submit your model for grading.   In order to do that, you need to save the model:

# %%
q_learner.save('trained_model.npz')

# %% [markdown]
# <a id='section9'></a>

# %% [markdown]
# ## Extra Credit

# %% [markdown]
# For extra credit, download the file <a href="mp11_extra.zip">mp11_extra.zip</a>.  The only important file in this package is:
# * `tests/test_extra.py`: this contains extra tests that will evaluate your pre-trained `deep_q` learner, which should be in a file called `trained_model.pkl`.  For full credit, your model should achieve an average score of greater than 20, averaged over 10 consecutive games.
#
# With a quantized lookup table, it's probably not possible to achieve an average score of 20.  With a deep-Q learner, however, it is eminently possible.  In order to do the extra credit, therefore, you should just fill in the part of `submitted.py` that implements the `deep_q` learner, using pytorch to define a model structure, train it, save it, load it, and act on it.  This learner only needs to have five methods: `__init__`, `act`, `learn`, `save`, and `load`:

# %%
importlib.reload(submitted)
help(submitted.deep_q.__init__)
# Out:
# Help on function __init__ in module submitted:
#
# __init__(self, alpha, epsilon, gamma, nfirst)
#     Create a new deep_q learner.
#     Your q_learner object should store the provided values of alpha,
#     epsilon, gamma, and nfirst.
#     It should also create a deep learning model that will accept
#     (state,action) as input, and estimate Q as the output.
#
#     @params:
#     alpha (scalar) - learning rate of the Q-learner
#     epsilon (scalar) - probability of taking a random action
#     gamma (scalar) - discount factor
#     nfirst (scalar) - exploring each state/action pair nfirst times before exploiting
#
#     @return:
#     None

# %%
help(submitted.deep_q.act)
# Out:
# Help on function act in module submitted:
#
# act(self, state)
#     Decide what action to take in the current state.
#     You are free to determine your own exploration/exploitation policy --
#     you don't need to use the epsilon and nfirst provided to you.
#
#     @params:
#     state: a list of 5 floats: ball_x, ball_y, ball_vx, ball_vy, paddle_y.
#
#     @return:
#     -1 if the paddle should move upward
#     0 if the paddle should be stationary
#     1 if the paddle should move downward

# %%
help(submitted.deep_q.learn)
# Out:
# Help on function learn in module submitted:
#
# learn(self, state, action, reward, newstate)
#     Perform one iteration of training on a deep-Q model.
#
#     @params:
#     state: a list of 5 floats: ball_x, ball_y, ball_vx, ball_vy, paddle_y
#     action: an integer, one of -1, 0, or +1
#     reward: a reward; positive for hitting the ball, negative for losing a game
#     newstate: a list of 5 floats, in the same format as state
#
#     @return:
#     None

# %%
help(submitted.deep_q.save)
# Out:
# Help on function save in module submitted:
#
# save(self, filename)
#     Save your trained deep-Q model to a file.
#     This can save in any format you like, as long as your "load"
#     function uses the same file format.
#
#     @params:
#     filename (str) - filename to which it should be saved
#     @return:
#     None

# %%
help(submitted.deep_q.load)
# Out:
# Help on function load in module submitted:
#
# load(self, filename)
#     Load your deep-Q model from a file.
#     This should load from whatever file format your save function
#     used.
#
#     @params:
#     filename (str) - filename from which it should be loaded
#     @return:
#     None

# %% [markdown]
# <a id='grade'></a>

# %% [markdown]
# ## Grade your homework

# %% [markdown]
# If you've reached this point, and all of the above sections work, then you're ready to try grading your homework!  Before you submit it to Gradescope, try grading it on your own machine.  This will run some visible test cases (which you can read in `tests/test_visible.py`), and compare the results to the solutions (which you can read in `solution.json`).
#
# The exclamation point (!) tells python to run the following as a shell command.  Obviously you don't need to run the code this way -- this usage is here just to remind you that you can also, if you wish, run this command in a terminal window.

# %%
# !python grade.py
# Out:
# EEEEE.....Completed 0 games, 16 rewards, 2500 frames, score 15, max score 15
# Completed 1 games, 80 rewards, 12506 frames, score 63, max score 63
# Completed 2 games, 92 rewards, 14475 frames, score 11, max score 63
# Completed 3 games, 142 rewards, 24803 frames, score 49, max score 63
# Completed 4 games, 184 rewards, 34429 frames, score 41, max score 63
# Completed 5 games, 201 rewards, 37492 frames, score 16, max score 63
# Completed 6 games, 246 rewards, 48948 frames, score 44, max score 63
# Completed 7 games, 321 rewards, 63337 frames, score 74, max score 74
# Completed 8 games, 350 rewards, 70008 frames, score 28, max score 74
# Completed 9 games, 354 rewards, 70707 frames, score 3, max score 74
# .
# ======================================================================
# ERROR: test_deep_q_exceeds_12 (test_extra.TestStep)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/jyou/Documents/ECE448/mp11/tests/test_extra.py", line 22, in test_deep_q_exceeds_12
#     q_learner.load('trained_model.pkl')
#   File "/Users/jyou/Documents/ECE448/mp11/submitted.py", line 333, in load
#     self.model.load_state_dict(torch.load(filename))
#   File "/Users/jyou/opt/anaconda3/lib/python3.9/site-packages/torch/serialization.py", line 699, in load
#     with _open_file_like(f, 'rb') as opened_file:
#   File "/Users/jyou/opt/anaconda3/lib/python3.9/site-packages/torch/serialization.py", line 230, in _open_file_like
#     return _open_file(name_or_buffer, mode)
#   File "/Users/jyou/opt/anaconda3/lib/python3.9/site-packages/torch/serialization.py", line 211, in __init__
#     super(_open_file, self).__init__(open(name, mode))
# FileNotFoundError: [Errno 2] No such file or directory: 'trained_model.pkl'
#
# ======================================================================
# ERROR: test_deep_q_exceeds_16 (test_extra.TestStep)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/jyou/Documents/ECE448/mp11/tests/test_extra.py", line 33, in test_deep_q_exceeds_16
#     q_learner.load('trained_model.pkl')
#   File "/Users/jyou/Documents/ECE448/mp11/submitted.py", line 333, in load
#     self.model.load_state_dict(torch.load(filename))
#   File "/Users/jyou/opt/anaconda3/lib/python3.9/site-packages/torch/serialization.py", line 699, in load
#     with _open_file_like(f, 'rb') as opened_file:
#   File "/Users/jyou/opt/anaconda3/lib/python3.9/site-packages/torch/serialization.py", line 230, in _open_file_like
#     return _open_file(name_or_buffer, mode)
#   File "/Users/jyou/opt/anaconda3/lib/python3.9/site-packages/torch/serialization.py", line 211, in __init__
#     super(_open_file, self).__init__(open(name, mode))
# FileNotFoundError: [Errno 2] No such file or directory: 'trained_model.pkl'
#
# ======================================================================
# ERROR: test_deep_q_exceeds_18 (test_extra.TestStep)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/jyou/Documents/ECE448/mp11/tests/test_extra.py", line 44, in test_deep_q_exceeds_18
#     q_learner.load('trained_model.pkl')
#   File "/Users/jyou/Documents/ECE448/mp11/submitted.py", line 333, in load
#     self.model.load_state_dict(torch.load(filename))
#   File "/Users/jyou/opt/anaconda3/lib/python3.9/site-packages/torch/serialization.py", line 699, in load
#     with _open_file_like(f, 'rb') as opened_file:
#   File "/Users/jyou/opt/anaconda3/lib/python3.9/site-packages/torch/serialization.py", line 230, in _open_file_like
#     return _open_file(name_or_buffer, mode)
#   File "/Users/jyou/opt/anaconda3/lib/python3.9/site-packages/torch/serialization.py", line 211, in __init__
#     super(_open_file, self).__init__(open(name, mode))
# FileNotFoundError: [Errno 2] No such file or directory: 'trained_model.pkl'
#
# ======================================================================
# ERROR: test_deep_q_exceeds_20 (test_extra.TestStep)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/jyou/Documents/ECE448/mp11/tests/test_extra.py", line 55, in test_deep_q_exceeds_20
#     q_learner.load('trained_model.pkl')
#   File "/Users/jyou/Documents/ECE448/mp11/submitted.py", line 333, in load
#     self.model.load_state_dict(torch.load(filename))
#   File "/Users/jyou/opt/anaconda3/lib/python3.9/site-packages/torch/serialization.py", line 699, in load
#     with _open_file_like(f, 'rb') as opened_file:
#   File "/Users/jyou/opt/anaconda3/lib/python3.9/site-packages/torch/serialization.py", line 230, in _open_file_like
#     return _open_file(name_or_buffer, mode)
#   File "/Users/jyou/opt/anaconda3/lib/python3.9/site-packages/torch/serialization.py", line 211, in __init__
#     super(_open_file, self).__init__(open(name, mode))
# FileNotFoundError: [Errno 2] No such file or directory: 'trained_model.pkl'
#
# ======================================================================
# ERROR: test_deep_q_exceeds_8 (test_extra.TestStep)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/jyou/Documents/ECE448/mp11/tests/test_extra.py", line 11, in test_deep_q_exceeds_8
#     q_learner.load('trained_model.pkl')
#   File "/Users/jyou/Documents/ECE448/mp11/submitted.py", line 333, in load
#     self.model.load_state_dict(torch.load(filename))
#   File "/Users/jyou/opt/anaconda3/lib/python3.9/site-packages/torch/serialization.py", line 699, in load
#     with _open_file_like(f, 'rb') as opened_file:
#   File "/Users/jyou/opt/anaconda3/lib/python3.9/site-packages/torch/serialization.py", line 230, in _open_file_like
#     return _open_file(name_or_buffer, mode)
#   File "/Users/jyou/opt/anaconda3/lib/python3.9/site-packages/torch/serialization.py", line 211, in __init__
#     super(_open_file, self).__init__(open(name, mode))
# FileNotFoundError: [Errno 2] No such file or directory: 'trained_model.pkl'
#
# ----------------------------------------------------------------------
# Ran 11 tests in 1.673s
#
# FAILED (errors=5)

# %% [markdown]
# Now you should try uploading your code to <a href="https://www.gradescope.com/courses/486387">Gradescope</a>.
#
# **Warning:** For this MP you need to update two files, not just one.
# * `trained_model.npz` should contain your trained model
# * `submitted.py` should contain your code that loads and runs your trained model.
#
# **Warning:** The autograder calculates the average score over ten random games.  If you are getting an average score above 10 almost all the time on your own computer, and if the autograder says you had a score below 10, try resubmitting to see if the next round of random games is better.
#
# **Extra Credit:** Your extra credit should also be uploaded as two files,
# * `trained_model.pkl` should contain your trained model
# * `submitted.py` should contain your code that loads and runs your trained model.
